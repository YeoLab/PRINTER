# %%
import pandas as pd
import pybedtools
from glob import glob

# %% [markdown]
# # Load peak files

# %%
peak_filepaths = sorted(glob('6_overlapped_confident_peaks/*cleaned.tsv'))

peak_filepaths


file_id_to_df = {}

for peak_filepath in peak_filepaths:    
    print(peak_filepath)
    file_id = peak_filepath.split('/')[-1].split('.tsv')[0]
    print('\t', file_id)
    file_id_to_df[file_id] = pd.read_csv(peak_filepath, sep='\t', index_col=0)
# Out:
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned.tsv
# 	 RBFOX2_ai_FOX2-8e_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned.tsv
# 	 RBFOX2_ai_FOX2-APOBEC1_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned.tsv
# 	 RBFOX2_ai_FOX2-MinA_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned.tsv
# 	 RBFOX2_ai_FOX2-P0078_cleaned
# 6_overlapped_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned.tsv
# 	 RBFOX2_both_FOX2-P0078_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned.tsv
# 	 RBFOX2_ct_FOX2-8e_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned.tsv
# 	 RBFOX2_ct_FOX2-APOBEC1_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned.tsv
# 	 RBFOX2_ct_FOX2-MinA_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-P0078_cleaned.tsv
# 	 RBFOX2_ct_FOX2-P0078_cleaned
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-8e_cleaned.tsv
# 	 SLBP_ai_SLBP-8e_cleaned
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-APOBEC1_cleaned.tsv
# 	 SLBP_ai_SLBP-APOBEC1_cleaned
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-MinA_cleaned.tsv
# 	 SLBP_ai_SLBP-MinA_cleaned
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-P0078_cleaned.tsv
# 	 SLBP_ai_SLBP-P0078_cleaned
# 6_overlapped_confident_peaks/SLBP_both_SLBP-P0078_cleaned.tsv
# 	 SLBP_both_SLBP-P0078_cleaned
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-8e_cleaned.tsv
# 	 SLBP_ct_SLBP-8e_cleaned
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-APOBEC1_cleaned.tsv
# 	 SLBP_ct_SLBP-APOBEC1_cleaned
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-MinA_cleaned.tsv
# 	 SLBP_ct_SLBP-MinA_cleaned
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-P0078_cleaned.tsv
# 	 SLBP_ct_SLBP-P0078_cleaned

# %% [markdown]
# # Make bedtools from peak files

# %%
file_id_to_bedtool = {}
for file_id, df in file_id_to_df.items():
    print(file_id)
    
    #df = df[df.score > .99]
    bedtool = pybedtools.BedTool.from_dataframe(df[['chrom', 'start', 'end', 'strand']])
    print('\t', len(bedtool))
    file_id_to_bedtool[file_id] = bedtool
# Out:
# RBFOX2_ai_FOX2-8e_cleaned
# 	 7882
# RBFOX2_ai_FOX2-APOBEC1_cleaned
# 	 540
# RBFOX2_ai_FOX2-MinA_cleaned
# 	 736
# RBFOX2_ai_FOX2-P0078_cleaned
# 	 3236
# RBFOX2_both_FOX2-P0078_cleaned
# 	 4003
# RBFOX2_ct_FOX2-8e_cleaned
# 	 729
# RBFOX2_ct_FOX2-APOBEC1_cleaned
# 	 1897
# RBFOX2_ct_FOX2-MinA_cleaned
# 	 338
# RBFOX2_ct_FOX2-P0078_cleaned
# 	 1151
# SLBP_ai_SLBP-8e_cleaned
# 	 1868
# SLBP_ai_SLBP-APOBEC1_cleaned
# 	 1091
# SLBP_ai_SLBP-MinA_cleaned
# 	 1271
# SLBP_ai_SLBP-P0078_cleaned
# 	 1180
# SLBP_both_SLBP-P0078_cleaned
# 	 1581
# SLBP_ct_SLBP-8e_cleaned
# 	 402
# SLBP_ct_SLBP-APOBEC1_cleaned
# 	 885
# SLBP_ct_SLBP-MinA_cleaned
# 	 398
# SLBP_ct_SLBP-P0078_cleaned
# 	 462

# %% [markdown]
# # Load regions in which to shuffle STAMP peaks

# %%
# Load regions
region_map_bedtool = pybedtools.BedTool('/projects/ps-yeolab3/ekofman/ReferenceData/peakcalling_regions/hg38/hg38_cellranger_region_map.bed')
len(region_map_bedtool)
# Out:
# 620869

# %% [markdown]
# # Figure out which region each peak was in

# %%
def add_index(r):
    return '{}:{}-{}({})'.format(r.chrom, r.start, r.end, r.strand)

# %%
names = 'chrom   start   end     edit_fraction   strand  target_bases    edited_bases    num_edited_reads        total_reads_in_region   fraction_reads_edited   mean_depth      num_substrate_bases     subregion_coverage      subregion_conversions   region_coverage region_conversions      gene_coverage   gene_conversions        score'.split()
#names = ['{}_region'.format(l) for l in names]
names
# Out:
# ['chrom',
#  'start',
#  'end',
#  'edit_fraction',
#  'strand',
#  'target_bases',
#  'edited_bases',
#  'num_edited_reads',
#  'total_reads_in_region',
#  'fraction_reads_edited',
#  'mean_depth',
#  'num_substrate_bases',
#  'subregion_coverage',
#  'subregion_conversions',
#  'region_coverage',
#  'region_conversions',
#  'gene_coverage',
#  'gene_conversions',
#  'score']

# %%
file_id_to_intersected = {}

for file_id, bedtool in file_id_to_bedtool.items():
    print(file_id)
    intersected = region_map_bedtool.intersect(bedtool, wa=True, wb=True).to_dataframe(names=['chrom_region', 'start_region', 'end_region', 'symbol_region', 'label_region', 'strand_region'] +names )

    intersected.index = intersected.apply(add_index, axis=1)
    intersected = intersected[(intersected.start >= intersected.start_region) & (intersected.end <= intersected.end_region)]
    intersected['peak_size'] = intersected['end'] - intersected['start']
    intersected = intersected[~intersected.index.duplicated(keep='first')]
    print('\t', len(intersected), len(bedtool))
    file_id_to_intersected[file_id] = intersected
# Out:
# RBFOX2_ai_FOX2-8e_cleaned
# 	 7838 7882
# RBFOX2_ai_FOX2-APOBEC1_cleaned
# 	 540 540
# RBFOX2_ai_FOX2-MinA_cleaned
# 	 732 736
# RBFOX2_ai_FOX2-P0078_cleaned
# 	 3232 3236
# RBFOX2_both_FOX2-P0078_cleaned
# 	 3997 4003
# RBFOX2_ct_FOX2-8e_cleaned
# 	 727 729
# RBFOX2_ct_FOX2-APOBEC1_cleaned
# 	 1895 1897
# RBFOX2_ct_FOX2-MinA_cleaned
# 	 337 338
# RBFOX2_ct_FOX2-P0078_cleaned
# 	 1149 1151
# SLBP_ai_SLBP-8e_cleaned
# 	 1854 1868
# SLBP_ai_SLBP-APOBEC1_cleaned
# 	 1080 1091
# SLBP_ai_SLBP-MinA_cleaned
# 	 1264 1271
# SLBP_ai_SLBP-P0078_cleaned
# 	 1174 1180
# SLBP_both_SLBP-P0078_cleaned
# 	 1573 1581
# SLBP_ct_SLBP-8e_cleaned
# 	 402 402
# SLBP_ct_SLBP-APOBEC1_cleaned
# 	 880 885
# SLBP_ct_SLBP-MinA_cleaned
# 	 397 398
# SLBP_ct_SLBP-P0078_cleaned
# 	 459 462

# %% [markdown]
# # Permute the STAMP peaks within their respective region

# %%
import random


NUM_RAND_REGIONS = 20

def get_randomized_region(chrom, start, end, strand, peak_size):
    random_regions = []
    for n in range(NUM_RAND_REGIONS):
        random_start = random.randint(start, end-peak_size)
        random_end = random_start + peak_size
        
        random_region = '{}:{}-{}({})'.format(chrom, random_start, random_end, strand)
        random_regions.append(random_region)
    
    return random_regions

# %%
def get_random_regions(chrom, start, end, peak_start, peak_end, strand):
    peak_size = peak_end - peak_start
    return get_randomized_region(chrom, start, end, strand, peak_size)

# %%
file_id_to_intersected.keys()
# Out:
# dict_keys(['RBFOX2_ai_FOX2-8e_cleaned', 'RBFOX2_ai_FOX2-APOBEC1_cleaned', 'RBFOX2_ai_FOX2-MinA_cleaned', 'RBFOX2_ai_FOX2-P0078_cleaned', 'RBFOX2_both_FOX2-P0078_cleaned', 'RBFOX2_ct_FOX2-8e_cleaned', 'RBFOX2_ct_FOX2-APOBEC1_cleaned', 'RBFOX2_ct_FOX2-MinA_cleaned', 'RBFOX2_ct_FOX2-P0078_cleaned', 'SLBP_ai_SLBP-8e_cleaned', 'SLBP_ai_SLBP-APOBEC1_cleaned', 'SLBP_ai_SLBP-MinA_cleaned', 'SLBP_ai_SLBP-P0078_cleaned', 'SLBP_both_SLBP-P0078_cleaned', 'SLBP_ct_SLBP-8e_cleaned', 'SLBP_ct_SLBP-APOBEC1_cleaned', 'SLBP_ct_SLBP-MinA_cleaned', 'SLBP_ct_SLBP-P0078_cleaned'])

# %%
file_id_to_shuffle_dfs = {}


for file_id, intersected in file_id_to_intersected.items():
    print(file_id)
    
    all_regions = []
    all_indices = []

    for r in intersected.iterrows():
        index = r[0]
        r = r[1]
        chrom = r.loc['chrom_region']
        start = r.loc['start_region']
        end = r.loc['end_region']
        peak_start = r.loc['start']
        peak_end = r.loc['end']
        strand = r.loc['strand_region']

        try:
            n_regions = get_random_regions(chrom, start, end, peak_start, peak_end, strand)
            all_regions.append(n_regions)

            all_indices.append(index)
        except Exception as e:
            print(chrom, start, end, peak_start, peak_end, strand)
            print(e)
            
    shuffle_df = pd.DataFrame(all_regions, index=all_indices)
    shuffle_df = shuffle_df[~shuffle_df.index.duplicated(keep='first')]
    
    print('\t', len(shuffle_df), len(shuffle_df.columns))
    file_id_to_shuffle_dfs[file_id] = shuffle_df
# Out:
# RBFOX2_ai_FOX2-8e_cleaned
# 	 7838 20
# RBFOX2_ai_FOX2-APOBEC1_cleaned
# 	 540 20
# RBFOX2_ai_FOX2-MinA_cleaned
# 	 732 20
# RBFOX2_ai_FOX2-P0078_cleaned
# 	 3232 20
# RBFOX2_both_FOX2-P0078_cleaned
# 	 3997 20
# RBFOX2_ct_FOX2-8e_cleaned
# 	 727 20
# RBFOX2_ct_FOX2-APOBEC1_cleaned
# 	 1895 20
# RBFOX2_ct_FOX2-MinA_cleaned
# 	 337 20
# RBFOX2_ct_FOX2-P0078_cleaned
# 	 1149 20
# SLBP_ai_SLBP-8e_cleaned
# 	 1854 20
# SLBP_ai_SLBP-APOBEC1_cleaned
# 	 1080 20
# SLBP_ai_SLBP-MinA_cleaned
# 	 1264 20
# SLBP_ai_SLBP-P0078_cleaned
# 	 1174 20
# SLBP_both_SLBP-P0078_cleaned
# 	 1573 20
# SLBP_ct_SLBP-8e_cleaned
# 	 402 20
# SLBP_ct_SLBP-APOBEC1_cleaned
# 	 880 20
# SLBP_ct_SLBP-MinA_cleaned
# 	 397 20
# SLBP_ct_SLBP-P0078_cleaned
# 	 459 20

# %% [markdown]
# # From aggregate dfs containing shuffled information, extract each column as a random bed file and save

# %%
def expand_string_to_df(label):
    chrom = label.split(':')[0]
    start = label.split(':')[1].split('-')[0]
    end = label.split(':')[1].split('-')[1].split('(')[0]
    strand = label.split('(')[1].split(')')[0]
    return chrom, start, end, strand


file_id_to_list_of_random_instance_dfs = {}


for file_id, shuffle_df in file_id_to_shuffle_dfs.items():
    print(file_id)
    random_instance_dfs = []

    for random_instance_index in shuffle_df.columns:
        print('{}/{}'.format(random_instance_index, len(shuffle_df.columns)))
        random_instance = shuffle_df[[random_instance_index]]
        random_instance_df = pd.DataFrame(zip(*random_instance[random_instance_index].apply(expand_string_to_df))).T
        random_instance_df.columns = ['chrom', 'start', 'end', 'strand']
        random_instance_dfs.append(random_instance_df)

    file_id_to_list_of_random_instance_dfs[file_id] = random_instance_dfs
# Out:
# RBFOX2_ai_FOX2-8e_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# RBFOX2_ai_FOX2-APOBEC1_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# RBFOX2_ai_FOX2-MinA_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# RBFOX2_ai_FOX2-P0078_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# RBFOX2_both_FOX2-P0078_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# RBFOX2_ct_FOX2-8e_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# RBFOX2_ct_FOX2-APOBEC1_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# RBFOX2_ct_FOX2-MinA_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# RBFOX2_ct_FOX2-P0078_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_ai_SLBP-8e_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_ai_SLBP-APOBEC1_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_ai_SLBP-MinA_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_ai_SLBP-P0078_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_both_SLBP-P0078_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_ct_SLBP-8e_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_ct_SLBP-APOBEC1_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_ct_SLBP-MinA_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20
# SLBP_ct_SLBP-P0078_cleaned
# 0/20
# 1/20
# 2/20
# 3/20
# 4/20
# 5/20
# 6/20
# 7/20
# 8/20
# 9/20
# 10/20
# 11/20
# 12/20
# 13/20
# 14/20
# 15/20
# 16/20
# 17/20
# 18/20
# 19/20

# %% [markdown]
# # Make directories into which to put shuffles

# %%
import os

for file_id, list_of_random_instance_dfs in file_id_to_list_of_random_instance_dfs.items():
    print(file_id)
    dir_name = '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/{}'.format(file_id)

    try:
        os.mkdir(dir_name)
    except Exception as e:
        print(e)
        
    # Save beds
    
    for i, df in enumerate(list_of_random_instance_dfs):
        df.to_csv('{}/{}_shuffle{}.tsv'.format(dir_name, file_id, i), index=False, sep='\t')
# Out:
# RBFOX2_ai_FOX2-8e_cleaned
# RBFOX2_ai_FOX2-APOBEC1_cleaned
# RBFOX2_ai_FOX2-MinA_cleaned
# RBFOX2_ai_FOX2-P0078_cleaned
# RBFOX2_both_FOX2-P0078_cleaned
# RBFOX2_ct_FOX2-8e_cleaned
# RBFOX2_ct_FOX2-APOBEC1_cleaned
# RBFOX2_ct_FOX2-MinA_cleaned
# RBFOX2_ct_FOX2-P0078_cleaned
# SLBP_ai_SLBP-8e_cleaned
# SLBP_ai_SLBP-APOBEC1_cleaned
# SLBP_ai_SLBP-MinA_cleaned
# SLBP_ai_SLBP-P0078_cleaned
# SLBP_both_SLBP-P0078_cleaned
# SLBP_ct_SLBP-8e_cleaned
# SLBP_ct_SLBP-APOBEC1_cleaned
# SLBP_ct_SLBP-MinA_cleaned
# SLBP_ct_SLBP-P0078_cleaned

# %%
sorted(glob('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/*'))
# Out:
# ['/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/FOX_motif_presence_in_shuffles.tsv',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_8e_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_APOBEC1_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_MinA_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_P0078_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_p0078_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_P0078_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_8e_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_APOBEC1_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-P0078',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-P0078_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_MinA_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_P0078_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_p0078_alone',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_8e_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_APOBEC1_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_MinA_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_P0078_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-8e',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-8e_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-APOBEC1',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-APOBEC1_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-MinA',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-MinA_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-P0078',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-P0078_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ai_SLBP-p0078',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_both_P0078_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_both_SLBP-P0078',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_both_SLBP-P0078_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_8e_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_APOBEC1_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_MinA_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_P0078_Only',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-8e',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-8e_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-APOBEC1',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-APOBEC1_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-p0078']

# %% [markdown]
# # Add sequences and motif presence

# %%
shuffled_peak_filepaths = [f for f in glob('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/*/*cleaned*') \
                           if 'with_sequence' not in f and 'motif_presence' not in f]
len(shuffled_peak_filepaths)
# Out:
# 360

# %%
shuffled_peak_filepaths[0:3]
# Out:
# ['/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle0.tsv',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle6.tsv',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle7.tsv']

# %%
from pyfaidx import Fasta
import re
fasta = '/projects/ps-yeolab3/ekofman/ReferenceData/hg38/cellranger-GRCh38-3.0.0/fasta/genome.fa'
FA = Fasta(fasta, rebuild=False)
import math

def get_sequence(r): 
    chrom = str(r.chrom)
    start = r.start
    end = r.end
    strand = r.strand
    
    sequence = FA[chrom][start:end].seq
    sequence = sequence.upper()
        
    return sequence

def get_extended_sequence(r): 
    chrom = str(r.chrom)
    
    midpoint = r.start + (int((r.end - r.start)/2))
    start = midpoint - 150
    end = midpoint + 150
    strand = r.strand
    
    sequence = FA[chrom][start:end].seq
    sequence = sequence.upper()
        
    return sequence

# %%
for peak_filepath in sorted(shuffled_peak_filepaths):
    print('Processing {}...'.format(peak_filepath))
    peak_df = pd.read_csv(peak_filepath, sep='\t')
    filename = peak_filepath.split('/')[-1]
    
    print('\tfilename is {}'.format(filename))
    
    folder = peak_filepath.split(filename)[0]
    print('\tfolder is {}'.format(folder))
    output_filepath = '{}/{}.with_sequence.bed'.format(folder, filename[0:-4])
    print(output_filepath)
    
    peak_df['sequence(+)'] = peak_df.apply(get_sequence, axis=1)
    peak_df['extended_sequence(+)'] = peak_df.apply(get_extended_sequence, axis=1)

    print('\tAssigned sequences')
    peak_df.to_csv(output_filepath, sep='\t', index=False)
    print('\tOutput file at {}'.format(output_filepath))
# Out:
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle0.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle0.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle0.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle0.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle1.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle1.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle1.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle1.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle10.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle10.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle10.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle10.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle11.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle11.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle11.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle11.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle12.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle12.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle12.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle12.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle13.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle13.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle13.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle13.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle14.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle14.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle14.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle14.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle15.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle15.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle15.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle15.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle16.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle16.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle16.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle16.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle17.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle17.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle17.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle17.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle18.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle18.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle18.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle18.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle19.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle19.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle19.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle19.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle2.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle2.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle2.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle2.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle3.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle3.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle3.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle3.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle4.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle4.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle4.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle4.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle5.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle5.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle5.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle5.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle6.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle6.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle6.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle6.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle7.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle7.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle7.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle7.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle8.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle8.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle8.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle8.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/RBFOX2_ai_FOX2-8e_cleaned_shuffle9.tsv...
# 	filename is RBFOX2_ai_FOX2-8e_cleaned_shuffle9.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle9.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned//RBFOX2_ai_FOX2-8e_cleaned_shuffle9.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle0.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle0.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle0.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle0.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle1.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle1.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle1.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle1.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle10.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle10.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle10.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle10.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle11.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle11.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle11.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle11.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle12.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle12.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle12.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle12.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle13.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle13.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle13.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle13.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle14.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle14.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle14.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle14.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle15.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle15.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle15.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle15.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle16.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle16.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle16.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle16.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle17.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle17.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle17.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle17.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle18.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle18.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle18.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle18.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle19.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle19.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle19.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle19.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle2.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle2.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle2.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle2.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle3.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle3.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle3.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle3.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle4.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle4.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle4.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle4.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle5.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle5.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle5.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle5.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle6.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle6.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle6.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle6.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle7.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle7.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle7.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle7.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle8.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle8.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle8.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle8.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle9.tsv...
# 	filename is RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle9.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle9.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle9.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle0.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle0.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle0.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle0.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle1.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle1.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle1.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle1.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle10.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle10.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle10.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle10.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle11.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle11.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle11.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle11.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle12.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle12.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle12.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle12.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle13.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle13.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle13.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle13.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle14.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle14.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle14.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle14.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle15.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle15.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle15.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle15.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle16.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle16.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle16.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle16.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle17.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle17.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle17.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle17.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle18.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle18.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle18.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle18.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle19.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle19.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle19.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle19.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle2.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle2.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle2.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle2.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle3.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle3.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle3.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle3.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle4.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle4.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle4.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle4.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle5.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle5.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle5.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle5.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle6.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle6.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle6.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle6.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle7.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle7.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle7.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle7.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle8.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle8.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle8.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle8.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/RBFOX2_ai_FOX2-MinA_cleaned_shuffle9.tsv...
# 	filename is RBFOX2_ai_FOX2-MinA_cleaned_shuffle9.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle9.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle9.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/RBFOX2_ai_FOX2-P0078_cleaned_shuffle0.tsv...
# 	filename is RBFOX2_ai_FOX2-P0078_cleaned_shuffle0.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle0.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle0.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/RBFOX2_ai_FOX2-P0078_cleaned_shuffle1.tsv...
# 	filename is RBFOX2_ai_FOX2-P0078_cleaned_shuffle1.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle1.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle1.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/RBFOX2_ai_FOX2-P0078_cleaned_shuffle10.tsv...
# 	filename is RBFOX2_ai_FOX2-P0078_cleaned_shuffle10.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle10.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle10.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/RBFOX2_ai_FOX2-P0078_cleaned_shuffle11.tsv...
# 	filename is RBFOX2_ai_FOX2-P0078_cleaned_shuffle11.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle11.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle11.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/RBFOX2_ai_FOX2-P0078_cleaned_shuffle12.tsv...
# 	filename is RBFOX2_ai_FOX2-P0078_cleaned_shuffle12.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle12.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle12.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/RBFOX2_ai_FOX2-P0078_cleaned_shuffle13.tsv...
# 	filename is RBFOX2_ai_FOX2-P0078_cleaned_shuffle13.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle13.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle13.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/RBFOX2_ai_FOX2-P0078_cleaned_shuffle14.tsv...
# 	filename is RBFOX2_ai_FOX2-P0078_cleaned_shuffle14.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle14.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle14.with_sequence.bed
# ...
# 	filename is SLBP_ct_SLBP-MinA_cleaned_shuffle7.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned//SLBP_ct_SLBP-MinA_cleaned_shuffle7.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned//SLBP_ct_SLBP-MinA_cleaned_shuffle7.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned/SLBP_ct_SLBP-MinA_cleaned_shuffle8.tsv...
# 	filename is SLBP_ct_SLBP-MinA_cleaned_shuffle8.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned//SLBP_ct_SLBP-MinA_cleaned_shuffle8.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned//SLBP_ct_SLBP-MinA_cleaned_shuffle8.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned/SLBP_ct_SLBP-MinA_cleaned_shuffle9.tsv...
# 	filename is SLBP_ct_SLBP-MinA_cleaned_shuffle9.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned//SLBP_ct_SLBP-MinA_cleaned_shuffle9.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-MinA_cleaned//SLBP_ct_SLBP-MinA_cleaned_shuffle9.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle0.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle0.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle0.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle0.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle1.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle1.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle1.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle1.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle10.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle10.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle10.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle10.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle11.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle11.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle11.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle11.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle12.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle12.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle12.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle12.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle13.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle13.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle13.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle13.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle14.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle14.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle14.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle14.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle15.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle15.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle15.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle15.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle16.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle16.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle16.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle16.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle17.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle17.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle17.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle17.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle18.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle18.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle18.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle18.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle19.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle19.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle19.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle19.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle2.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle2.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle2.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle2.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle3.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle3.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle3.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle3.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle4.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle4.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle4.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle4.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle5.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle5.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle5.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle5.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle6.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle6.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle6.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle6.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle7.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle7.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle7.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle7.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle8.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle8.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle8.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle8.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/SLBP_ct_SLBP-P0078_cleaned_shuffle9.tsv...
# 	filename is SLBP_ct_SLBP-P0078_cleaned_shuffle9.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle9.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/SLBP_ct_SLBP-P0078_cleaned//SLBP_ct_SLBP-P0078_cleaned_shuffle9.with_sequence.bed

# %% [markdown]
# # Determine motif presence in shuffled sequence-assigned .bed files

# %%
complement = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A'}
def reverse_complement(seq):
    return "".join(complement.get(base, base) for base in reversed(seq))

def reverse(seq):
    return seq[::-1]

def motif_present(sequence, motif, strand):
    if strand == '+':
        return motif in sequence
    elif strand == '-':
        return reverse_complement(motif) in sequence

def motif_distance_from_center(sequence, motif, strand):
    #print(sequence)
    if strand == '+':
        search_term = motif
    elif strand == '-':
        search_term = reverse_complement(motif)
    
    if search_term in sequence:
        closest_position_in_first_half = 1000
        closest_position_in_second_half = 1000
        
        midpoint = math.ceil(len(sequence)/2)
        #print('\tmidpoint is {}'.format(midpoint))
        start_of_second_half = midpoint-len(motif)

        sequence_first_half = sequence[0:midpoint]
        sequence_second_half = sequence[start_of_second_half:]

        #print('\tSplit:', sequence_first_half, sequence_second_half)
        if search_term in sequence_first_half:
            flipped_sequence = reverse(sequence_first_half)
            flipped_search_term = reverse(search_term)
            
            #print('searching for {} in {}'.format(flipped_search_term, flipped_sequence))
            closest_position_in_first_half = - flipped_sequence.index(flipped_search_term) - math.floor(len(motif)/2)
            
        if search_term in sequence_second_half:
            closest_position_in_second_half = sequence_second_half.index(search_term) - math.floor(len(motif)/2)

        if min(abs(closest_position_in_second_half), abs(closest_position_in_first_half)) == abs(closest_position_in_second_half):
            return closest_position_in_second_half
        else:
            return closest_position_in_first_half
    else:
        return None
    
motifs = ['TGCATG']#, 'GAATG', 'GTTTG', 'GTGTG', 'GTATG', 'GCTTG', 'GCCTG']

def add_sequence_presences(r, window_size=70):
    extended_sequence = r['extended_sequence(+)']
    strand = r.strand

    distance = motif_distance_from_center(extended_sequence, 'TGCATG', strand)
    
    sequence = r['sequence(+)']

    presence_map = {motif: motif_present(sequence, motif, strand) for motif in motifs}
    #return presence_map.get(motifs[0]), presence_map.get(motifs[1]), presence_map.get(motifs[2]), presence_map.get(motifs[3]), presence_map.get(motifs[4]), presence_map.get(motifs[5]), presence_map.get(motifs[6]), distance
    return presence_map.get(motifs[0]), distance

def calculate_fractions(p_df):
    fractions_dict = {}
    counts_dict = {}
    
    for motif in motifs:# + ['any_motif']:
        motif_present_count = p_df[motif].sum()
        motif_present_fraction = motif_present_count/len(p_df)
        fractions_dict[motif] = motif_present_fraction
        counts_dict[motif] = motif_present_count
    
    return fractions_dict, counts_dict

### tests
print(motif_present('TGCATG', 'TGCATG', '+'))
print(motif_present('TGCATG', 'TGCATG', '-'))
print(motif_present('TGCATG', 'CATGCA', '-'))

print(reverse('GCATG'))

print(motif_distance_from_center('GCATGZZZZZZZZZZ', 'GCATG', '+'))
print(motif_distance_from_center('ZZZZZGCATGZZZZZ', 'GCATG', '+'))
print(motif_distance_from_center('ZZZZZZGCATGZZZZ', 'GCATG', '+'))
print(motif_distance_from_center('ZZZZZZZGCATGZZZ', 'GCATG', '+'))
print(motif_distance_from_center('ZZZZZZZZZZGCATG', 'GCATG', '+'))
print(motif_distance_from_center('GCATGZGCATGZZZZZ', 'BAB', '+'))
print(motif_distance_from_center('ZZZGCATGZZZGCATG', 'GCATG', '+'))
print(motif_distance_from_center('AAGCATGCATGCATGCATGCATGA', 'GCATG', '+'))
# Out:
# True
# False
# True
# GTACG
# -5
# 0
# 1
# 2
# 5
# None
# -2
# 1

# %%
shuffled_peak_with_sequence_filepaths = glob('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/*/*cleaned*with_sequence.bed')

# %%
len(shuffled_peak_with_sequence_filepaths)
# Out:
# 360

# %%
all_fractions = pd.DataFrame()
all_counts = pd.DataFrame()

num_peak_per_sample_id = {}

for filepath in shuffled_peak_with_sequence_filepaths:
    # Extract sample ID from filepath
    sample_id = filepath.split('/')[-1].split('.with_sequence.bed')[0]
    
    if 'SLBP' in sample_id:
        continue
    else:
        folder = filepath.split(sample_id)[0]

        print('\t', folder, sample_id)

        output_filename = '{}/{}.motif_presence.bed'.format(folder, sample_id)
        print('\t\t', output_filename)

        print('\t...Reading...')
        p_df = pd.read_csv(filepath, sep='\t')
        num_peaks = len(p_df)
        num_peak_per_sample_id[sample_id] = num_peaks

        # Calculate sequence presence
        #p_df[motifs[0]],p_df[motifs[1]],p_df[motifs[2]],p_df[motifs[3]],p_df[motifs[4]],p_df[motifs[5]],p_df[motifs[6]],p_df['GCATG_dist_from_center'] = zip(*p_df.apply(add_sequence_presences, axis=1))
        p_df[motifs[0]],p_df['TGCATG_dist_from_center'] = zip(*p_df.apply(add_sequence_presences, axis=1))

        print('\tOutputting file {}'.format(output_filename))

        #p_df['any_motif'] = p_df[[motifs[0], motifs[1], motifs[2], motifs[3], motifs[4], motifs[5], motifs[6]]].any(axis=1)

        p_df.to_csv(output_filename, sep='\t', index=False, header=True)

        new_fractions_dict, new_counts_dict = calculate_fractions(p_df)

        new_fractions = pd.DataFrame.from_dict(new_fractions_dict, orient='index', columns=[sample_id])
        new_counts = pd.DataFrame.from_dict(new_counts_dict, orient='index', columns=[sample_id])    

        if all_fractions.empty:
            all_fractions = new_fractions
        else:
            all_fractions = all_fractions.join(new_fractions, how='inner')

        if all_counts.empty:
            all_counts = new_counts
        else:
            all_counts = all_counts.join(new_counts, how='inner')
        print('\t', len(all_fractions.columns))

#all_fractions[sorted(all_fractions.columns)].to_csv('7_shuffled_confident_peaks/FOX_motif_presence_in_shuffles.tsv', sep='\t')
all_fractions[sorted(all_fractions.columns)].to_csv('7_shuffled_confident_peaks/FOX_cleaned_motif_presence_in_shuffles.tsv', sep='\t')
# Out:
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle7
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle7.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle7.motif_presence.bed
# 	 1
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle15
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle15.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle15.motif_presence.bed
# 	 2
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle19
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle19.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle19.motif_presence.bed
# 	 3
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle4
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle4.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle4.motif_presence.bed
# 	 4
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle0
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle0.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle0.motif_presence.bed
# 	 5
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle18
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle18.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle18.motif_presence.bed
# 	 6
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle10
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle10.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle10.motif_presence.bed
# 	 7
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle16
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle16.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle16.motif_presence.bed
# 	 8
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle2
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle2.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle2.motif_presence.bed
# 	 9
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle5
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle5.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle5.motif_presence.bed
# 	 10
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle14
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle14.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle14.motif_presence.bed
# 	 11
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle17
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle17.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle17.motif_presence.bed
# 	 12
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle6
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle6.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle6.motif_presence.bed
# 	 13
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle11
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle11.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle11.motif_presence.bed
# 	 14
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle3
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle3.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle3.motif_presence.bed
# 	 15
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle12
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle12.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle12.motif_presence.bed
# 	 16
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle8
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle8.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle8.motif_presence.bed
# 	 17
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle1
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle1.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle1.motif_presence.bed
# 	 18
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle13
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle13.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle13.motif_presence.bed
# 	 19
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned/ RBFOX2_ai_FOX2-MinA_cleaned_shuffle9
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle9.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned//RBFOX2_ai_FOX2-MinA_cleaned_shuffle9.motif_presence.bed
# 	 20
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle11
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle11.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle11.motif_presence.bed
# 	 21
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle12
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle12.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle12.motif_presence.bed
# 	 22
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle17
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle17.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle17.motif_presence.bed
# 	 23
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle3
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle3.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle3.motif_presence.bed
# 	 24
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle10
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle10.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle10.motif_presence.bed
# 	 25
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle4
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle4.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle4.motif_presence.bed
# 	 26
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle16
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle16.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle16.motif_presence.bed
# 	 27
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle2
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle2.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle2.motif_presence.bed
# 	 28
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle9
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle9.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle9.motif_presence.bed
# 	 29
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle1
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle1.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle1.motif_presence.bed
# 	 30
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle13
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle13.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle13.motif_presence.bed
# 	 31
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle7
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle7.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle7.motif_presence.bed
# 	 32
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle15
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle15.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle15.motif_presence.bed
# 	 33
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle8
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle8.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle8.motif_presence.bed
# 	 34
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle14
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle14.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle14.motif_presence.bed
# 	 35
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle5
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle5.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle5.motif_presence.bed
# 	 36
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle6
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle6.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle6.motif_presence.bed
# 	 37
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle19
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle19.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle19.motif_presence.bed
# 	 38
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle0
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle0.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle0.motif_presence.bed
# 	 39
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned/ RBFOX2_ct_FOX2-MinA_cleaned_shuffle18
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle18.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned//RBFOX2_ct_FOX2-MinA_cleaned_shuffle18.motif_presence.bed
# 	 40
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle3
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle3.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle3.motif_presence.bed
# 	 41
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle18
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle18.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle18.motif_presence.bed
# 	 42
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle6
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle6.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle6.motif_presence.bed
# 	 43
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle8
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle8.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle8.motif_presence.bed
# 	 44
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle4
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle4.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle4.motif_presence.bed
# 	 45
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle10
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle10.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle10.motif_presence.bed
# 	 46
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle14
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle14.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle14.motif_presence.bed
# 	 47
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle12
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle12.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle12.motif_presence.bed
# 	 48
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle16
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle16.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle16.motif_presence.bed
# 	 49
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle7
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle7.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle7.motif_presence.bed
# 	 50
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle15
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle15.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle15.motif_presence.bed
# 	 51
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle9
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle9.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle9.motif_presence.bed
# 	 52
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle13
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle13.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle13.motif_presence.bed
# 	 53
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle2
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle2.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle2.motif_presence.bed
# 	 54
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle0
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle0.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle0.motif_presence.bed
# 	 55
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle5
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle5.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle5.motif_presence.bed
# 	 56
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle19
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle19.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle19.motif_presence.bed
# 	 57
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle1
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle1.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle1.motif_presence.bed
# 	 58
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle11
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle11.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle11.motif_presence.bed
# 	 59
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned/ RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle17
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle17.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned//RBFOX2_ct_FOX2-APOBEC1_cleaned_shuffle17.motif_presence.bed
# 	 60
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle0
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle0.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle0.motif_presence.bed
# 	 61
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle1
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle1.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle1.motif_presence.bed
# 	 62
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle7
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle7.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle7.motif_presence.bed
# 	 63
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle9
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle9.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle9.motif_presence.bed
# 	 64
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle5
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle5.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle5.motif_presence.bed
# 	 65
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle4
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle4.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle4.motif_presence.bed
# 	 66
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle14
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle14.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle14.motif_presence.bed
# 	 67
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle17
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle17.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle17.motif_presence.bed
# 	 68
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle13
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle13.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle13.motif_presence.bed
# 	 69
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle15
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle15.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle15.motif_presence.bed
# 	 70
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle8
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle8.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle8.motif_presence.bed
# 	 71
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle10
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle10.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle10.motif_presence.bed
# 	 72
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle16
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle16.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle16.motif_presence.bed
# 	 73
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle19
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle19.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle19.motif_presence.bed
# 	 74
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle2
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle2.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle2.motif_presence.bed
# 	 75
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle18
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle18.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle18.motif_presence.bed
# 	 76
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle12
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle12.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle12.motif_presence.bed
# 	 77
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle6
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle6.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle6.motif_presence.bed
# 	 78
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle11
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle11.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle11.motif_presence.bed
# 	 79
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned/ RBFOX2_ct_FOX2-8e_cleaned_shuffle3
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle3.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned//RBFOX2_ct_FOX2-8e_cleaned_shuffle3.motif_presence.bed
# 	 80
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle7
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle7.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle7.motif_presence.bed
# 	 81
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle13
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle13.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle13.motif_presence.bed
# 	 82
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle11
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle11.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle11.motif_presence.bed
# 	 83
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle10
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle10.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle10.motif_presence.bed
# 	 84
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle0
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle0.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle0.motif_presence.bed
# 	 85
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle16
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle16.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle16.motif_presence.bed
# 	 86
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle2
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle2.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle2.motif_presence.bed
# 	 87
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle5
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle5.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle5.motif_presence.bed
# 	 88
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle4
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle4.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle4.motif_presence.bed
# 	 89
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle12
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle12.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle12.motif_presence.bed
# 	 90
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned/ RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle17
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned//RBFOX2_ai_FOX2-APOBEC1_cleaned_shuffle17.motif_presence.bed
# 	...Reading...
# ...
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle19.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle19.motif_presence.bed
# 	 151
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle12
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle12.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle12.motif_presence.bed
# 	 152
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle16
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle16.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle16.motif_presence.bed
# 	 153
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle0
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle0.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle0.motif_presence.bed
# 	 154
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle2
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle2.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle2.motif_presence.bed
# 	 155
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle10
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle10.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle10.motif_presence.bed
# 	 156
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle3
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle3.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle3.motif_presence.bed
# 	 157
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle17
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle17.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle17.motif_presence.bed
# 	 158
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle6
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle6.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle6.motif_presence.bed
# 	 159
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned/ RBFOX2_both_FOX2-P0078_cleaned_shuffle13
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle13.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned//RBFOX2_both_FOX2-P0078_cleaned_shuffle13.motif_presence.bed
# 	 160
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle17
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle17.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle17.motif_presence.bed
# 	 161
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle5
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle5.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle5.motif_presence.bed
# 	 162
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle15
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle15.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle15.motif_presence.bed
# 	 163
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle14
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle14.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle14.motif_presence.bed
# 	 164
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle10
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle10.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle10.motif_presence.bed
# 	 165
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle1
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle1.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle1.motif_presence.bed
# 	 166
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle0
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle0.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle0.motif_presence.bed
# 	 167
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle19
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle19.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle19.motif_presence.bed
# 	 168
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle3
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle3.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle3.motif_presence.bed
# 	 169
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle12
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle12.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle12.motif_presence.bed
# 	 170
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle16
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle16.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle16.motif_presence.bed
# 	 171
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle4
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle4.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle4.motif_presence.bed
# 	 172
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle2
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle2.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle2.motif_presence.bed
# 	 173
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle13
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle13.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle13.motif_presence.bed
# 	 174
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle9
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle9.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle9.motif_presence.bed
# 	 175
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle7
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle7.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle7.motif_presence.bed
# 	 176
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle18
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle18.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle18.motif_presence.bed
# 	 177
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle11
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle11.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle11.motif_presence.bed
# 	 178
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle8
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle8.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle8.motif_presence.bed
# 	 179
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned/ RBFOX2_ai_FOX2-P0078_cleaned_shuffle6
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle6.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned//RBFOX2_ai_FOX2-P0078_cleaned_shuffle6.motif_presence.bed
# 	 180

# %%
all_fractions
# Out:
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle7  \
# TGCATG                              0.047814
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle15  \
# TGCATG                               0.045082
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle19  \
# TGCATG                               0.062842
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle4  \
# TGCATG                              0.056011
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle0  \
# TGCATG                              0.051913
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle18  \
# TGCATG                               0.051913
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle10  \
# TGCATG                               0.054645
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle16  \
# TGCATG                               0.056011
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle2  \
# TGCATG                              0.038251
#
#         RBFOX2_ai_FOX2-MinA_cleaned_shuffle5  ...  \
# TGCATG                              0.043716  ...
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle16  \
# TGCATG                                0.035582
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle4  \
# TGCATG                               0.034653
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle2  \
# TGCATG                               0.031869
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle13  \
# TGCATG                                0.033106
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle9  \
# TGCATG                               0.034035
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle7  \
# TGCATG                               0.032488
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle18  \
# TGCATG                                0.035891
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle11  \
# TGCATG                                0.035582
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle8  \
# TGCATG                               0.034653
#
#         RBFOX2_ai_FOX2-P0078_cleaned_shuffle6
# TGCATG                               0.029084
#
# [1 rows x 180 columns]

# %%
pybedtools.cleanup()

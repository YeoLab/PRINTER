# %%
import pandas as pd
import pybedtools
from glob import glob

# %% [markdown]
# # Load peak files

# %%
import pybedtools 

peak_filepaths = sorted(glob('9.4_unioned_peaks/*.bed'))

peak_filepaths


file_id_to_bedtool = {}

for peak_filepath in peak_filepaths:    
    print(peak_filepath)
    file_id = peak_filepath.split('/')[-1].split('.tsv')[0]
    print('\t', file_id)
    file_id_to_bedtool[file_id] = pybedtools.BedTool(peak_filepath)
# Out:
# 9.4_unioned_peaks/unioned_cleaned_peaks.bed
# 	 unioned_cleaned_peaks.bed

# %% [markdown]
# # Load regions in which to shuffle STAMP peaks

# %%
# Load regions
region_map_bedtool = pybedtools.BedTool('/projects/ps-yeolab3/ekofman/ReferenceData/peakcalling_regions/hg38/hg38_cellranger_region_map.bed')
len(region_map_bedtool)
# Out:
# 620869

# %% [markdown]
# # Figure out which region each peak was in

# %%
def add_index(r):
    return '{}:{}-{}({})'.format(r.chrom, r.start, r.end, r.strand)

# %%
names = 'chrom   start   end     edit_fraction   strand  target_bases    edited_bases    num_edited_reads        total_reads_in_region   fraction_reads_edited   mean_depth      num_substrate_bases     subregion_coverage      subregion_conversions   region_coverage region_conversions      gene_coverage   gene_conversions        score'.split()
#names = ['{}_region'.format(l) for l in names]
names
# Out:
# ['chrom',
#  'start',
#  'end',
#  'edit_fraction',
#  'strand',
#  'target_bases',
#  'edited_bases',
#  'num_edited_reads',
#  'total_reads_in_region',
#  'fraction_reads_edited',
#  'mean_depth',
#  'num_substrate_bases',
#  'subregion_coverage',
#  'subregion_conversions',
#  'region_coverage',
#  'region_conversions',
#  'gene_coverage',
#  'gene_conversions',
#  'score']

# %%
file_id_to_intersected = {}

for file_id, bedtool in file_id_to_bedtool.items():
    print(file_id)
    intersected = region_map_bedtool.intersect(bedtool, wa=True, wb=True).to_dataframe(names=['chrom_region', 'start_region', 'end_region', 'symbol_region', 'label_region', 'strand_region'] +names )

    intersected.index = intersected.apply(add_index, axis=1)
    intersected = intersected[(intersected.start >= intersected.start_region) & (intersected.end <= intersected.end_region)]
    intersected['peak_size'] = intersected['end'] - intersected['start']
    intersected = intersected[~intersected.index.duplicated(keep='first')]
    print('\t', len(intersected), len(bedtool))
    file_id_to_intersected[file_id] = intersected
# Out:
# unioned_cleaned_peaks.bed
# 	 11067 11123

# %% [markdown]
# # Permute the STAMP peaks within their respective region

# %%
import random


NUM_RAND_REGIONS = 100

def get_randomized_region(chrom, start, end, strand, peak_size):
    random_regions = []
    for n in range(NUM_RAND_REGIONS):
        random_start = random.randint(start, end-peak_size)
        random_end = random_start + peak_size
        
        random_region = '{}:{}-{}({})'.format(chrom, random_start, random_end, strand)
        random_regions.append(random_region)
    
    return random_regions

# %%
def get_random_regions(chrom, start, end, peak_start, peak_end, strand):
    peak_size = peak_end - peak_start
    return get_randomized_region(chrom, start, end, strand, peak_size)

# %%
file_id_to_intersected.keys()
# Out:
# dict_keys(['unioned_cleaned_peaks.bed'])

# %%
file_id_to_shuffle_dfs = {}


for file_id, intersected in file_id_to_intersected.items():
    print(file_id)
    
    all_regions = []
    all_indices = []

    for r in intersected.iterrows():
        index = r[0]
        r = r[1]
        chrom = r.loc['chrom_region']
        start = r.loc['start_region']
        end = r.loc['end_region']
        peak_start = r.loc['start']
        peak_end = r.loc['end']
        strand = r.loc['strand_region']

        try:
            n_regions = get_random_regions(chrom, start, end, peak_start, peak_end, strand)
            all_regions.append(n_regions)

            all_indices.append(index)
        except Exception as e:
            print(chrom, start, end, peak_start, peak_end, strand)
            print(e)
            
    shuffle_df = pd.DataFrame(all_regions, index=all_indices)
    shuffle_df = shuffle_df[~shuffle_df.index.duplicated(keep='first')]
    
    print('\t', len(shuffle_df), len(shuffle_df.columns))
    file_id_to_shuffle_dfs[file_id] = shuffle_df
# Out:
# unioned_cleaned_peaks.bed
# 	 11067 100

# %% [markdown]
# # From aggregate dfs containing shuffled information, extract each column as a random bed file and save

# %%
def expand_string_to_df(label):
    chrom = label.split(':')[0]
    start = label.split(':')[1].split('-')[0]
    end = label.split(':')[1].split('-')[1].split('(')[0]
    strand = label.split('(')[1].split(')')[0]
    return chrom, start, end, strand


file_id_to_list_of_random_instance_dfs = {}


for file_id, shuffle_df in file_id_to_shuffle_dfs.items():
    print(file_id)
    random_instance_dfs = []

    for random_instance_index in shuffle_df.columns:
        print('{}/{}'.format(random_instance_index, len(shuffle_df.columns)))
        random_instance = shuffle_df[[random_instance_index]]
        random_instance_df = pd.DataFrame(zip(*random_instance[random_instance_index].apply(expand_string_to_df))).T
        random_instance_df.columns = ['chrom', 'start', 'end', 'strand']
        random_instance_dfs.append(random_instance_df)

    file_id_to_list_of_random_instance_dfs[file_id] = random_instance_dfs
# Out:
# unioned_cleaned_peaks.bed
# 0/100
# 1/100
# 2/100
# 3/100
# 4/100
# 5/100
# 6/100
# 7/100
# 8/100
# 9/100
# 10/100
# 11/100
# 12/100
# 13/100
# 14/100
# 15/100
# 16/100
# 17/100
# 18/100
# 19/100
# 20/100
# 21/100
# 22/100
# 23/100
# 24/100
# 25/100
# 26/100
# 27/100
# 28/100
# 29/100
# 30/100
# 31/100
# 32/100
# 33/100
# 34/100
# 35/100
# 36/100
# 37/100
# 38/100
# 39/100
# 40/100
# 41/100
# 42/100
# 43/100
# 44/100
# 45/100
# 46/100
# 47/100
# 48/100
# 49/100
# 50/100
# 51/100
# 52/100
# 53/100
# 54/100
# 55/100
# 56/100
# 57/100
# 58/100
# 59/100
# 60/100
# 61/100
# 62/100
# 63/100
# 64/100
# 65/100
# 66/100
# 67/100
# 68/100
# 69/100
# 70/100
# 71/100
# 72/100
# 73/100
# 74/100
# 75/100
# 76/100
# 77/100
# 78/100
# 79/100
# 80/100
# 81/100
# 82/100
# 83/100
# 84/100
# 85/100
# 86/100
# 87/100
# 88/100
# 89/100
# 90/100
# 91/100
# 92/100
# 93/100
# 94/100
# 95/100
# 96/100
# 97/100
# 98/100
# 99/100

# %% [markdown]
# # Make directories into which to put shuffles

# %%
import os

for file_id, list_of_random_instance_dfs in file_id_to_list_of_random_instance_dfs.items():
    print(file_id)
    dir_name = '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/{}'.format(file_id)

    try:
        os.mkdir(dir_name)
    except Exception as e:
        print(e)
        
    # Save beds
    
    for i, df in enumerate(list_of_random_instance_dfs):
        df.to_csv('{}/{}_shuffle{}.tsv'.format(dir_name, file_id, i), index=False, sep='\t')
# Out:
# unioned_cleaned_peaks.bed

# %%
sorted(glob('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/*'))
# Out:
# ['/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed']

# %% [markdown]
# # Add sequences and motif presence

# %%
shuffled_peak_filepaths = [f for f in glob('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/*/*') \
                           if 'with_sequence' not in f and 'motif_presence' not in f]
len(shuffled_peak_filepaths)
# Out:
# 100

# %%
shuffled_peak_filepaths[0:3]
# Out:
# ['/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle16.tsv',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle3.tsv',
#  '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle23.tsv']

# %%
from pyfaidx import Fasta
import re
fasta = '/projects/ps-yeolab3/ekofman/ReferenceData/hg38/cellranger-GRCh38-3.0.0/fasta/genome.fa'
FA = Fasta(fasta, rebuild=False)
import math

def get_sequence(r): 
    chrom = str(r.chrom)
    start = r.start
    end = r.end
    strand = r.strand
    
    sequence = FA[chrom][start:end].seq
    sequence = sequence.upper()
        
    return sequence

def get_extended_sequence(r): 
    chrom = str(r.chrom)
    
    midpoint = r.start + (int((r.end - r.start)/2))
    start = midpoint - 150
    end = midpoint + 150
    strand = r.strand
    
    sequence = FA[chrom][start:end].seq
    sequence = sequence.upper()
        
    return sequence

# %%
for peak_filepath in sorted(shuffled_peak_filepaths):
    print('Processing {}...'.format(peak_filepath))
    peak_df = pd.read_csv(peak_filepath, sep='\t')
    filename = peak_filepath.split('/')[-1]
    
    print('\tfilename is {}'.format(filename))
    
    folder = peak_filepath.split(filename)[0]
    print('\tfolder is {}'.format(folder))
    output_filepath = '{}/{}.with_sequence.bed'.format(folder, filename[0:-4])
    print(output_filepath)
    
    peak_df['sequence(+)'] = peak_df.apply(get_sequence, axis=1)
    peak_df['extended_sequence(+)'] = peak_df.apply(get_extended_sequence, axis=1)

    print('\tAssigned sequences')
    peak_df.to_csv(output_filepath, sep='\t', index=False)
    print('\tOutput file at {}'.format(output_filepath))
# Out:
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle0.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle0.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle0.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle0.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle1.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle1.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle1.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle1.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle10.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle10.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle10.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle10.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle11.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle11.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle11.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle11.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle12.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle12.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle12.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle12.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle13.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle13.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle13.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle13.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle14.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle14.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle14.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle14.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle15.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle15.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle15.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle15.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle16.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle16.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle16.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle16.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle17.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle17.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle17.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle17.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle18.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle18.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle18.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle18.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle19.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle19.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle19.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle19.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle2.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle2.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle2.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle2.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle20.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle20.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle20.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle20.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle21.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle21.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle21.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle21.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle22.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle22.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle22.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle22.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle23.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle23.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle23.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle23.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle24.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle24.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle24.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle24.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle25.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle25.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle25.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle25.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle26.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle26.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle26.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle26.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle27.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle27.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle27.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle27.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle28.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle28.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle28.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle28.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle29.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle29.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle29.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle29.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle3.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle3.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle3.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle3.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle30.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle30.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle30.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle30.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle31.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle31.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle31.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle31.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle32.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle32.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle32.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle32.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle33.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle33.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle33.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle33.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle34.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle34.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle34.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle34.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle35.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle35.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle35.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle35.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle36.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle36.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle36.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle36.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle37.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle37.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle37.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle37.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle38.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle38.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle38.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle38.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle39.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle39.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle39.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle39.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle4.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle4.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle4.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle4.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle40.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle40.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle40.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle40.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle41.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle41.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle41.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle41.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle42.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle42.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle42.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle42.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle43.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle43.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle43.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle43.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle44.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle44.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle44.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle44.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle45.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle45.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle45.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle45.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle46.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle46.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle46.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle46.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle47.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle47.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle47.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle47.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle48.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle48.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle48.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle48.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle49.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle49.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle49.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle49.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle5.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle5.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle5.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle5.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle50.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle50.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle50.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle50.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle51.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle51.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle51.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle51.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle52.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle52.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle52.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle52.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle53.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle53.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle53.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle53.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle54.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle54.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle54.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle54.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle55.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle55.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle55.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle55.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle56.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle56.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle56.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle56.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle57.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle57.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle57.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle57.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle58.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle58.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle58.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle58.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle59.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle59.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle59.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle59.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle6.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle6.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle6.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle6.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle60.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle60.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle60.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle60.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle61.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle61.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle61.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle61.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle62.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle62.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle62.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle62.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle63.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle63.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle63.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle63.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle64.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle64.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle64.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle64.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle65.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle65.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle65.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle65.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle66.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle66.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle66.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle66.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle67.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle67.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle67.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle67.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle68.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle68.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle68.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle68.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle69.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle69.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle69.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle69.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle7.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle7.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle7.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle7.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle70.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle70.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle70.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle70.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle71.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle71.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# ...
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle79.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle79.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle79.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle79.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle8.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle8.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle8.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle8.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle80.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle80.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle80.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle80.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle81.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle81.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle81.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle81.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle82.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle82.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle82.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle82.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle83.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle83.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle83.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle83.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle84.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle84.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle84.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle84.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle85.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle85.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle85.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle85.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle86.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle86.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle86.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle86.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle87.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle87.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle87.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle87.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle88.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle88.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle88.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle88.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle89.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle89.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle89.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle89.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle9.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle9.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle9.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle9.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle90.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle90.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle90.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle90.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle91.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle91.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle91.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle91.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle92.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle92.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle92.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle92.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle93.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle93.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle93.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle93.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle94.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle94.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle94.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle94.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle95.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle95.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle95.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle95.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle96.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle96.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle96.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle96.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle97.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle97.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle97.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle97.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle98.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle98.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle98.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle98.with_sequence.bed
# Processing /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/unioned_cleaned_peaks.bed_shuffle99.tsv...
# 	filename is unioned_cleaned_peaks.bed_shuffle99.tsv
# 	folder is /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/
# /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle99.with_sequence.bed
# 	Assigned sequences
# 	Output file at /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle99.with_sequence.bed

# %% [markdown]
# # Determine motif presence in shuffled sequence-assigned .bed files

# %%
complement = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A'}
def reverse_complement(seq):
    return "".join(complement.get(base, base) for base in reversed(seq))

def reverse(seq):
    return seq[::-1]

def motif_present(sequence, motif, strand):
    if strand == '+':
        return motif in sequence
    elif strand == '-':
        return reverse_complement(motif) in sequence

def motif_distance_from_center(sequence, motif, strand):
    #print(sequence)
    if strand == '+':
        search_term = motif
    elif strand == '-':
        search_term = reverse_complement(motif)
    
    if search_term in sequence:
        closest_position_in_first_half = 1000
        closest_position_in_second_half = 1000
        
        midpoint = math.ceil(len(sequence)/2)
        #print('\tmidpoint is {}'.format(midpoint))
        start_of_second_half = midpoint-len(motif)

        sequence_first_half = sequence[0:midpoint]
        sequence_second_half = sequence[start_of_second_half:]

        #print('\tSplit:', sequence_first_half, sequence_second_half)
        if search_term in sequence_first_half:
            flipped_sequence = reverse(sequence_first_half)
            flipped_search_term = reverse(search_term)
            
            #print('searching for {} in {}'.format(flipped_search_term, flipped_sequence))
            closest_position_in_first_half = - flipped_sequence.index(flipped_search_term) - math.floor(len(motif)/2)
            
        if search_term in sequence_second_half:
            closest_position_in_second_half = sequence_second_half.index(search_term) - math.floor(len(motif)/2)

        if min(abs(closest_position_in_second_half), abs(closest_position_in_first_half)) == abs(closest_position_in_second_half):
            return closest_position_in_second_half
        else:
            return closest_position_in_first_half
    else:
        return None
    
motifs = ['TGCATG']#, 'GAATG', 'GTTTG', 'GTGTG', 'GTATG', 'GCTTG', 'GCCTG']

def add_sequence_presences(r, window_size=70):
    extended_sequence = r['extended_sequence(+)']
    strand = r.strand

    distance = motif_distance_from_center(extended_sequence, 'TGCATG', strand)
    
    sequence = r['sequence(+)']

    presence_map = {motif: motif_present(sequence, motif, strand) for motif in motifs}
    #return presence_map.get(motifs[0]), presence_map.get(motifs[1]), presence_map.get(motifs[2]), presence_map.get(motifs[3]), presence_map.get(motifs[4]), presence_map.get(motifs[5]), presence_map.get(motifs[6]), distance
    return presence_map.get(motifs[0]), distance

def calculate_fractions(p_df):
    fractions_dict = {}
    counts_dict = {}
    
    for motif in motifs:# + ['any_motif']:
        motif_present_count = p_df[motif].sum()
        motif_present_fraction = motif_present_count/len(p_df)
        fractions_dict[motif] = motif_present_fraction
        counts_dict[motif] = motif_present_count
    
    return fractions_dict, counts_dict

### tests
print(motif_present('TGCATG', 'TGCATG', '+'))
print(motif_present('TGCATG', 'TGCATG', '-'))
print(motif_present('TGCATG', 'CATGCA', '-'))

print(reverse('GCATG'))

print(motif_distance_from_center('GCATGZZZZZZZZZZ', 'GCATG', '+'))
print(motif_distance_from_center('ZZZZZGCATGZZZZZ', 'GCATG', '+'))
print(motif_distance_from_center('ZZZZZZGCATGZZZZ', 'GCATG', '+'))
print(motif_distance_from_center('ZZZZZZZGCATGZZZ', 'GCATG', '+'))
print(motif_distance_from_center('ZZZZZZZZZZGCATG', 'GCATG', '+'))
print(motif_distance_from_center('GCATGZGCATGZZZZZ', 'BAB', '+'))
print(motif_distance_from_center('ZZZGCATGZZZGCATG', 'GCATG', '+'))
print(motif_distance_from_center('AAGCATGCATGCATGCATGCATGA', 'GCATG', '+'))
# Out:
# True
# False
# True
# GTACG
# -5
# 0
# 1
# 2
# 5
# None
# -2
# 1

# %%
shuffled_peak_with_sequence_filepaths = glob('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/*/*with_sequence.bed')

# %%
len(shuffled_peak_with_sequence_filepaths)
# Out:
# 100

# %%
all_fractions = pd.DataFrame()
all_counts = pd.DataFrame()

num_peak_per_sample_id = {}

for filepath in shuffled_peak_with_sequence_filepaths:
    # Extract sample ID from filepath
    sample_id = filepath.split('/')[-1].split('.with_sequence.bed')[0]
    
    if 'SLBP' in sample_id:
        continue
    else:
        folder = filepath.split(sample_id)[0]

        print('\t', folder, sample_id)

        output_filename = '{}/{}.motif_presence.bed'.format(folder, sample_id)
        print('\t\t', output_filename)

        print('\t...Reading...')
        p_df = pd.read_csv(filepath, sep='\t')
        num_peaks = len(p_df)
        num_peak_per_sample_id[sample_id] = num_peaks

        # Calculate sequence presence
        #p_df[motifs[0]],p_df[motifs[1]],p_df[motifs[2]],p_df[motifs[3]],p_df[motifs[4]],p_df[motifs[5]],p_df[motifs[6]],p_df['GCATG_dist_from_center'] = zip(*p_df.apply(add_sequence_presences, axis=1))
        p_df[motifs[0]],p_df['TGCATG_dist_from_center'] = zip(*p_df.apply(add_sequence_presences, axis=1))

        print('\tOutputting file {}'.format(output_filename))

        #p_df['any_motif'] = p_df[[motifs[0], motifs[1], motifs[2], motifs[3], motifs[4], motifs[5], motifs[6]]].any(axis=1)

        p_df.to_csv(output_filename, sep='\t', index=False, header=True)

        new_fractions_dict, new_counts_dict = calculate_fractions(p_df)

        new_fractions = pd.DataFrame.from_dict(new_fractions_dict, orient='index', columns=[sample_id])
        new_counts = pd.DataFrame.from_dict(new_counts_dict, orient='index', columns=[sample_id])    

        if all_fractions.empty:
            all_fractions = new_fractions
        else:
            all_fractions = all_fractions.join(new_fractions, how='inner')

        if all_counts.empty:
            all_counts = new_counts
        else:
            all_counts = all_counts.join(new_counts, how='inner')
        print('\t', len(all_fractions.columns))

all_fractions[sorted(all_fractions.columns)].to_csv('9.4_shuffled_union_peaks/FOX_cleaned_motif_presence_in_union_shuffles.tsv', sep='\t')
# Out:
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle68
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle68.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle68.motif_presence.bed
# 	 1
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle42
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle42.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle42.motif_presence.bed
# 	 2
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle8
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle8.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle8.motif_presence.bed
# 	 3
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle59
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle59.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle59.motif_presence.bed
# 	 4
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle72
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle72.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle72.motif_presence.bed
# 	 5
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle64
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle64.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle64.motif_presence.bed
# 	 6
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle97
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle97.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle97.motif_presence.bed
# 	 7
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle23
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle23.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle23.motif_presence.bed
# 	 8
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle1
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle1.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle1.motif_presence.bed
# 	 9
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle77
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle77.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle77.motif_presence.bed
# 	 10
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle54
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle54.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle54.motif_presence.bed
# 	 11
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle75
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle75.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle75.motif_presence.bed
# 	 12
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle4
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle4.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle4.motif_presence.bed
# 	 13
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle3
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle3.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle3.motif_presence.bed
# 	 14
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle46
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle46.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle46.motif_presence.bed
# 	 15
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle79
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle79.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle79.motif_presence.bed
# 	 16
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle45
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle45.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle45.motif_presence.bed
# 	 17
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle86
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle86.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle86.motif_presence.bed
# 	 18
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle80
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle80.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle80.motif_presence.bed
# 	 19
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle22
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle22.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle22.motif_presence.bed
# 	 20
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle81
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle81.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle81.motif_presence.bed
# 	 21
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle87
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle87.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle87.motif_presence.bed
# 	 22
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle41
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle41.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle41.motif_presence.bed
# 	 23
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle12
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle12.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle12.motif_presence.bed
# 	 24
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle43
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle43.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle43.motif_presence.bed
# 	 25
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle5
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle5.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle5.motif_presence.bed
# 	 26
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle67
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle67.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle67.motif_presence.bed
# 	 27
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle26
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle26.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle26.motif_presence.bed
# 	 28
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle53
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle53.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle53.motif_presence.bed
# 	 29
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle58
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle58.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle58.motif_presence.bed
# 	 30
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle99
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle99.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle99.motif_presence.bed
# 	 31
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle56
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle56.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle56.motif_presence.bed
# 	 32
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle10
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle10.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle10.motif_presence.bed
# 	 33
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle33
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle33.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle33.motif_presence.bed
# 	 34
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle20
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle20.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle20.motif_presence.bed
# 	 35
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle65
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle65.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle65.motif_presence.bed
# 	 36
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle44
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle44.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle44.motif_presence.bed
# 	 37
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle2
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle2.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle2.motif_presence.bed
# 	 38
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle6
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle6.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle6.motif_presence.bed
# 	 39
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle90
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle90.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle90.motif_presence.bed
# 	 40
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle62
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle62.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle62.motif_presence.bed
# 	 41
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle15
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle15.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle15.motif_presence.bed
# 	 42
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle84
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle84.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle84.motif_presence.bed
# 	 43
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle61
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle61.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle61.motif_presence.bed
# 	 44
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle31
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle31.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle31.motif_presence.bed
# 	 45
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle48
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle48.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle48.motif_presence.bed
# 	 46
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle14
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle14.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle14.motif_presence.bed
# 	 47
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle60
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle60.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle60.motif_presence.bed
# 	 48
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle91
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle91.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle91.motif_presence.bed
# 	 49
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle57
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle57.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle57.motif_presence.bed
# 	 50
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle13
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle13.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle13.motif_presence.bed
# 	 51
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle70
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle70.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle70.motif_presence.bed
# 	 52
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle88
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle88.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle88.motif_presence.bed
# 	 53
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle78
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle78.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle78.motif_presence.bed
# 	 54
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle35
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle35.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle35.motif_presence.bed
# 	 55
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle19
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle19.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle19.motif_presence.bed
# 	 56
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle69
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle69.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle69.motif_presence.bed
# 	 57
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle40
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle40.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle40.motif_presence.bed
# 	 58
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle0
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle0.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle0.motif_presence.bed
# 	 59
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle49
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle49.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle49.motif_presence.bed
# 	 60
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle51
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle51.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle51.motif_presence.bed
# 	 61
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle36
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle36.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle36.motif_presence.bed
# 	 62
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle21
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle21.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle21.motif_presence.bed
# 	 63
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle52
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle52.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle52.motif_presence.bed
# 	 64
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle29
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle29.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle29.motif_presence.bed
# 	 65
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle89
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle89.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle89.motif_presence.bed
# 	 66
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle94
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle94.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle94.motif_presence.bed
# 	 67
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle98
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle98.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle98.motif_presence.bed
# 	 68
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle7
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle7.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle7.motif_presence.bed
# 	 69
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle28
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle28.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle28.motif_presence.bed
# 	 70
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle17
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle17.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle17.motif_presence.bed
# 	 71
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle39
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle39.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle39.motif_presence.bed
# 	 72
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle92
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle92.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle92.motif_presence.bed
# 	 73
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle96
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle96.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle96.motif_presence.bed
# 	 74
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle55
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle55.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle55.motif_presence.bed
# 	 75
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle82
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle82.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle82.motif_presence.bed
# 	 76
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle85
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle85.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle85.motif_presence.bed
# 	 77
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle18
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle18.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle18.motif_presence.bed
# 	 78
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle30
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle30.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle30.motif_presence.bed
# 	 79
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle93
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle93.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle93.motif_presence.bed
# 	 80
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle9
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle9.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle9.motif_presence.bed
# 	 81
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle63
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle63.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle63.motif_presence.bed
# 	 82
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle24
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle24.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle24.motif_presence.bed
# 	 83
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle11
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle11.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle11.motif_presence.bed
# 	 84
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle47
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle47.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle47.motif_presence.bed
# 	 85
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle50
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle50.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle50.motif_presence.bed
# 	 86
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle34
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle34.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle34.motif_presence.bed
# 	 87
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle73
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle73.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle73.motif_presence.bed
# 	 88
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle83
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle83.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle83.motif_presence.bed
# 	 89
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle25
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle25.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle25.motif_presence.bed
# 	 90
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle38
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle38.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle38.motif_presence.bed
# 	 91
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle16
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle16.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle16.motif_presence.bed
# 	 92
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle95
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle95.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle95.motif_presence.bed
# 	 93
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle76
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle76.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle76.motif_presence.bed
# 	 94
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle27
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle27.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle27.motif_presence.bed
# 	 95
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle37
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle37.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle37.motif_presence.bed
# 	 96
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle66
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle66.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle66.motif_presence.bed
# 	 97
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle32
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle32.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle32.motif_presence.bed
# 	 98
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle71
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle71.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle71.motif_presence.bed
# 	 99
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed/ unioned_cleaned_peaks.bed_shuffle74
# 		 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle74.motif_presence.bed
# 	...Reading...
# 	Outputting file /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/9.4_shuffled_union_peaks/unioned_cleaned_peaks.bed//unioned_cleaned_peaks.bed_shuffle74.motif_presence.bed
# 	 100

# %%
all_fractions
# Out:
#         unioned_cleaned_peaks.bed_shuffle68  \
# TGCATG                             0.043824
#
#         unioned_cleaned_peaks.bed_shuffle42  \
# TGCATG                             0.044818
#
#         unioned_cleaned_peaks.bed_shuffle8  \
# TGCATG                            0.041836
#
#         unioned_cleaned_peaks.bed_shuffle59  \
# TGCATG                             0.041113
#
#         unioned_cleaned_peaks.bed_shuffle72  \
# TGCATG                             0.044547
#
#         unioned_cleaned_peaks.bed_shuffle64  \
# TGCATG                             0.042378
#
#         unioned_cleaned_peaks.bed_shuffle97  \
# TGCATG                             0.044999
#
#         unioned_cleaned_peaks.bed_shuffle23  \
# TGCATG                             0.046535
#
#         unioned_cleaned_peaks.bed_shuffle1  \
# TGCATG                             0.04021
#
#         unioned_cleaned_peaks.bed_shuffle77  ...  \
# TGCATG                             0.045179  ...
#
#         unioned_cleaned_peaks.bed_shuffle38  \
# TGCATG                              0.04283
#
#         unioned_cleaned_peaks.bed_shuffle16  \
# TGCATG                              0.04283
#
#         unioned_cleaned_peaks.bed_shuffle95  \
# TGCATG                             0.041655
#
#         unioned_cleaned_peaks.bed_shuffle76  \
# TGCATG                             0.041926
#
#         unioned_cleaned_peaks.bed_shuffle27  \
# TGCATG                             0.042107
#
#         unioned_cleaned_peaks.bed_shuffle37  \
# TGCATG                             0.044095
#
#         unioned_cleaned_peaks.bed_shuffle66  \
# TGCATG                             0.042378
#
#         unioned_cleaned_peaks.bed_shuffle32  \
# TGCATG                             0.043463
#
#         unioned_cleaned_peaks.bed_shuffle71  \
# TGCATG                              0.04283
#
#         unioned_cleaned_peaks.bed_shuffle74
# TGCATG                             0.040661
#
# [1 rows x 100 columns]

# %%
pybedtools.cleanup()

# %%
import pandas as pd
from glob import glob
import pybedtools
from collections import defaultdict

# %%
figures_directory = '/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/Figures/RBFOX2_motif_permutations/'

# %% [markdown]
# # shuffles of eCLIP peaks -- fraction overlapped by STAMP peaks

# %% [markdown]
# # Load STAMP peaks

# %% [raw]
# import pandas as pd
# import pybedtools
#
# stamp_file_bedtools = {}
# stamp_file_dfs = {}
# for s in sorted(stamp_files):
#     print(s)
#     description = s.split('/')[-1]
#     print('\t', description)
#
#     stamp_file_df = pd.read_csv(s, sep='\t', index_col=0)
#
#     stamp_file_dfs[description] = stamp_file_df[['chrom', 'start', 'end', 'strand']]
#     stamp_file_bedtools[description] = pybedtools.BedTool.from_dataframe(stamp_file_df[['chrom', 'start', 'end', 'strand', 'strand', 'strand']])

# %% [markdown]
# # load shuffled stamp peaks

# %%
shuffled_peak_with_sequence_filepaths = glob('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/7_shuffled_confident_peaks/*/*with_sequence.bed')

# %%
len(shuffled_peak_with_sequence_filepaths)
# Out:
# 1160

# %% [markdown]
# # Compare permuted fraction for motif

# %%
permuted_fractions = pd.read_csv('7_shuffled_confident_peaks/FOX_motif_presence_in_shuffles.tsv', sep='\t', index_col=0)
permuted_fractions_cleaned = pd.read_csv('7_shuffled_confident_peaks/FOX_cleaned_motif_presence_in_shuffles.tsv', sep='\t', index_col=0)

permuted_fractions = pd.concat([permuted_fractions, permuted_fractions_cleaned], axis=1)

# %%
peak_set_to_motif_presence = defaultdict(lambda:[])
for l, v in permuted_fractions.loc['TGCATG'].items():
    #print(l, v)
    main_category = l.split('_shuffle')[0]
    peak_set_to_motif_presence[main_category].append(v)

# %%
peak_set_to_motif_presence
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'RBFOX2_ai_8e_alone': [0.0253058175366514,
#               0.0236249883275749,
#               0.0224110561210197,
#               0.0243720235316089,
#               0.0218507797179942,
#               0.0241852647306004,
#               0.0236249883275749,
#               0.0216640209169857,
#               0.0244654029321131,
#               0.0259594733401811,
#               0.0243720235316089,
#               0.0234382295265664,
#               0.0250256793351386,
#               0.0274535437482491,
#               0.0253058175366514,
#               0.0200765711084134,
#               0.0240918853300961,
#               0.0230647119245494,
#               0.0217574003174899,
#               0.0236249883275749],
#              'RBFOX2_ai_APOBEC1_alone': [0.0267489711934156,
#               0.0185185185185185,
#               0.0267489711934156,
#               0.0288065843621399,
#               0.0246913580246913,
#               0.0205761316872428,
#               0.0267489711934156,
#               0.0246913580246913,
#               0.0308641975308641,
#               0.0267489711934156,
#               0.0267489711934156,
#               0.0329218106995884,
#               0.0267489711934156,
#               0.0308641975308641,
#               0.0164609053497942,
#               0.0123456790123456,
#               0.0205761316872428,
#               0.0164609053497942,
#               0.0164609053497942,
#               0.0390946502057613],
#              'RBFOX2_ai_FOX2-8e': [0.0395594996257885,
#               0.0408425104244627,
#               0.0440500374211483,
#               0.0410563455575751,
#               0.0405217577247941,
#               0.042767026622474,
#               0.0384903239602266,
#               0.0403079225916818,
#               0.0409494279910189,
#               0.0405217577247941,
#               0.0390249117930075,
#               0.0431946968886988,
#               0.039880252325457,
#               0.0392387469261199,
#               0.0405217577247941,
#               0.0408425104244627,
#               0.0400940874585694,
#               0.0408425104244627,
#               0.0414840158237998,
#               0.0416978509569122],
#              'RBFOX2_ai_FOX2-APOBEC1': [0.0179257362355953,
#               0.0179257362355953,
#               0.0230473751600512,
#               0.026888604353393,
#               0.0204865556978233,
#               0.0243277848911651,
#               0.026888604353393,
#               0.0166453265044814,
#               0.026888604353393,
#               0.0204865556978233,
#               0.0256081946222791,
#               0.0217669654289372,
#               0.0243277848911651,
#               0.029449423815621,
#               0.0179257362355953,
#               0.0256081946222791,
#               0.0204865556978233,
#               0.0320102432778489,
#               0.029449423815621,
#               0.029449423815621],
#              'RBFOX2_ai_FOX2-MinA': [0.0420258620689655,
#               0.0452586206896551,
#               0.0549568965517241,
#               0.043103448275862,
#               0.0420258620689655,
#               0.0441810344827586,
#               0.0441810344827586,
#               0.0409482758620689,
#               0.0366379310344827,
#               0.0387931034482758,
#               0.0452586206896551,
#               0.0495689655172413,
#               0.043103448275862,
#               0.0420258620689655,
#               0.052801724137931,
#               0.043103448275862,
#               0.0495689655172413,
#               0.0474137931034482,
#               0.0506465517241379,
#               0.0560344827586206],
#              'RBFOX2_ai_FOX2-P0078': [0.0321759259259259,
#               0.0333333333333333,
#               0.0310185185185185,
#               0.0298611111111111,
#               0.0335648148148148,
#               0.0254629629629629,
#               0.0321759259259259,
#               0.0280092592592592,
#               0.0289351851851851,
#               0.0273148148148148,
#               0.0344907407407407,
#               0.0273148148148148,
#               0.0298611111111111,
#               0.0268518518518518,
#               0.0305555555555555,
#               0.0296296296296296,
#               0.0298611111111111,
#               0.0333333333333333,
#               0.0319444444444444,
#               0.0344907407407407],
#              'RBFOX2_ai_MinA_alone': [0.0333333333333333,
#               0.0222222222222222,
#               0.024074074074074,
#               0.0185185185185185,
#               0.0203703703703703,
#               0.0333333333333333,
#               0.0203703703703703,
#               0.0129629629629629,
#               0.0351851851851851,
#               0.024074074074074,
#               0.0259259259259259,
#               0.0074074074074074,
#               0.0259259259259259,
#               0.024074074074074,
#               0.0296296296296296,
#               0.0222222222222222,
#               0.0185185185185185,
#               0.0203703703703703,
#               0.024074074074074,
#               0.0296296296296296],
#              'RBFOX2_ai_P0078_alone': [0.0187380497131931,
#               0.0141491395793499,
#               0.0177820267686424,
#               0.0139579349904397,
#               0.0173996175908221,
#               0.0151051625239005,
#               0.0156787762906309,
#               0.0147227533460803,
#               0.0149139579349904,
#               0.0179732313575525,
#               0.0181644359464627,
#               0.0151051625239005,
#               0.0166347992351816,
#               0.0145315487571701,
#               0.0147227533460803,
#               0.0179732313575525,
#               0.0152963671128107,
#               0.0152963671128107,
#               0.0128107074569789,
#               0.0177820267686424],
#              'RBFOX2_ai_p0078_alone': [0.0156667940389759,
#               0.015284677111196,
#               0.0149025601834161,
#               0.0149025601834161,
#               0.0145204432556362,
#               0.0177684371417653,
#               0.0154757355750859,
#               0.0173863202139854,
#               0.0162399694306457,
#               0.0147115017195261,
#               0.0137562094000764,
#               0.0129919755445166,
#               0.0160489109667558,
#               0.0137562094000764,
#               0.015284677111196,
#               0.0143293847917462,
#               0.015093618647306,
#               0.015093618647306,
#               0.019105846388995,
#               0.0175773786778754],
#              'RBFOX2_both_FOX2-P0078': [0.0318331503841931,
#               0.0289059641419685,
#               0.0349432857665569,
#               0.0289059641419685,
#               0.0298207098426637,
#               0.0267105744603,
#               0.0318331503841931,
#               0.0300036589828027,
#               0.0323819978046103,
#               0.0300036589828027,
#               0.031284302963776,
#               0.0325649469447493,
#               0.0285400658616904,
#               0.0279912184412733,
#               0.0281741675814123,
#               0.0309184046834979,
#               0.0305525064032199,
#               0.0287230150018294,
#               0.0307354555433589,
#               0.031284302963776],
#              'RBFOX2_both_P0078_alone': [0.0138512496236073,
#               0.0133995784402288,
#               0.0173140620295091,
#               0.014453477868112,
#               0.0158084914182475,
#               0.0146040349292381,
#               0.014453477868112,
#               0.0176151761517615,
#               0.0132490213791026,
#               0.0150557061126166,
#               0.0152062631737428,
#               0.0155073772959951,
#               0.0152062631737428,
#               0.0168623908461306,
#               0.0140018066847335,
#               0.0137006925624811,
#               0.0149051490514905,
#               0.0177657332128876,
#               0.0152062631737428,
#               0.0155073772959951],
#              'RBFOX2_ct_8e_alone': [0.0158311345646438,
#               0.0131926121372031,
#               0.0237467018469656,
#               0.0131926121372031,
#               0.0158311345646438,
#               0.0026385224274406,
#               0.0079155672823219,
#               0.0158311345646438,
#               0.0079155672823219,
#               0.0184696569920844,
#               0.0079155672823219,
#               0.0105540897097625,
#               0.0158311345646438,
#               0.0026385224274406,
#               0.0105540897097625,
#               0.0131926121372031,
#               0.0026385224274406,
#               0.0105540897097625,
#               0.0052770448548812,
#               0.0105540897097625],
#              'RBFOX2_ct_APOBEC1_alone': [0.0210371819960861,
#               0.0215264187866927,
#               0.0293542074363992,
#               0.0195694716242661,
#               0.022504892367906,
#               0.022504892367906,
#               0.0200587084148727,
#               0.0185909980430528,
#               0.0181017612524461,
#               0.023972602739726,
#               0.0229941291585127,
#               0.0200587084148727,
#               0.0195694716242661,
#               0.0176125244618395,
#               0.022504892367906,
#               0.0234833659491193,
#               0.023972602739726,
#               0.0220156555772994,
#               0.0210371819960861,
#               0.0244618395303326],
#              'RBFOX2_ct_FOX2-8e': [0.0101123595505617,
#               0.0123595505617977,
#               0.0089887640449438,
#               0.0044943820224719,
#               0.0101123595505617,
#               0.0089887640449438,
#               0.0123595505617977,
#               0.0146067415730337,
#               0.0067415730337078,
#               0.0123595505617977,
#               0.0089887640449438,
#               0.0089887640449438,
#               0.0157303370786516,
#               0.0089887640449438,
#               0.0056179775280898,
#               0.0089887640449438,
#               0.0123595505617977,
#               0.0168539325842696,
#               0.0168539325842696,
#               0.0089887640449438],
#              'RBFOX2_ct_FOX2-APOBEC1': [0.0381374722838137,
#               0.037250554323725,
#               0.0337028824833702,
#               0.0412416851441241,
#               0.0381374722838137,
#               0.0412416851441241,
#               0.0399113082039911,
#               0.0381374722838137,
#               0.0412416851441241,
#               0.038580931263858,
#               0.0425720620842572,
#               0.0407982261640798,
#               0.0452328159645232,
#               0.0412416851441241,
#               0.0399113082039911,
#               0.0407982261640798,
#               0.0376940133037694,
#               0.0390243902439024,
#               0.0407982261640798,
#               0.0345898004434589],
#              'RBFOX2_ct_FOX2-MinA': [0.01171875,
#               0.01171875,
#               0.01171875,
#               0.001953125,
#               0.0078125,
#               0.013671875,
#               0.009765625,
#               0.0078125,
#               0.009765625,
#               0.01171875,
#               0.01171875,
#               0.005859375,
#               0.009765625,
#               0.01171875,
#               0.009765625,
#               0.015625,
#               0.01171875,
#               0.01953125,
#               0.00390625,
#               0.005859375],
#              'RBFOX2_ct_FOX2-P0078': [0.0210006176652254,
#               0.0197652872143298,
#               0.0259419394688079,
#               0.0166769610870907,
#               0.019147621988882,
#               0.0247066090179122,
#               0.0203829524397776,
#               0.0253242742433601,
#               0.0166769610870907,
#               0.0247066090179122,
#               0.0216182828906732,
#               0.0253242742433601,
#               0.0172946263125386,
#               0.0240889437924644,
#               0.022235948116121,
#               0.022235948116121,
#               0.0197652872143298,
#               0.0271772699197035,
#               0.0216182828906732,
#               0.0265596046942557],
#              'RBFOX2_ct_MinA_alone': [0.0170575692963752,
#               0.0149253731343283,
#               0.0106609808102345,
#               0.0170575692963752,
#               0.0127931769722814,
#               0.0085287846481876,
#               0.0106609808102345,
#               0.0085287846481876,
#               0.0149253731343283,
#               0.0170575692963752,
#               0.0106609808102345,
#               0.0085287846481876,
#               0.0063965884861407,
#               0.0,
#               0.0106609808102345,
#               0.0127931769722814,
#               0.0063965884861407,
#               0.0063965884861407,
#               0.021321961620469,
#               0.0085287846481876],
#              'RBFOX2_ct_P0078_alone': [0.0104931794333683,
#               0.0167890870933892,
#               0.0167890870933892,
#               0.0110178384050367,
#               0.0120671563483735,
#               0.0120671563483735,
#               0.0110178384050367,
#               0.0188877229800629,
#               0.015215110178384,
#               0.0141657922350472,
#               0.0136411332633788,
#               0.015215110178384,
#               0.0094438614900314,
#               0.0146904512067156,
#               0.0162644281217208,
#               0.0110178384050367,
#               0.0141657922350472,
#               0.0136411332633788,
#               0.0131164742917103,
#               0.0125918153200419],
#              'RBFOX2_ct_p0078_alone': [0.010465724751439,
#               0.0109890109890109,
#               0.0167451596023024,
#               0.0141287284144427,
#               0.0162218733647305,
#               0.0130821559392987,
#               0.0130821559392987,
#               0.0167451596023024,
#               0.0146520146520146,
#               0.0109890109890109,
#               0.009942438513867,
#               0.0156985871271585,
#               0.0120355834641548,
#               0.0151753008895866,
#               0.010465724751439,
#               0.0120355834641548,
#               0.0088958660387231,
#               0.0167451596023024,
#               0.0156985871271585,
#               0.0130821559392987],
#              'RBFOX2_ai_FOX2-8e_cleaned': [0.0403164072467466,
#               0.0419749936208216,
#               0.0458025006379178,
#               0.0391681551416177,
#               0.0426129114570043,
#               0.0422301607552947,
#               0.0431232457259505,
#               0.0435059964276601,
#               0.0404439908139831,
#               0.0438887471293697,
#               0.0409543250829293,
#               0.0413370757846389,
#               0.0413370757846389,
#               0.0404439908139831,
#               0.041592242919112,
#               0.0443990813983158,
#               0.0421025771880581,
#               0.044909415667262,
#               0.0408267415156927,
#               0.0421025771880581],
#              'RBFOX2_ai_FOX2-APOBEC1_cleaned': [0.0166666666666666,
#               0.0203703703703703,
#               0.0148148148148148,
#               0.0185185185185185,
#               0.0296296296296296,
#               0.0185185185185185,
#               0.0277777777777777,
#               0.0222222222222222,
#               0.0185185185185185,
#               0.0333333333333333,
#               0.0148148148148148,
#               0.0203703703703703,
#               0.0185185185185185,
#               0.0148148148148148,
#               0.0222222222222222,
#               0.0129629629629629,
#               0.0148148148148148,
#               0.0074074074074074,
#               0.0185185185185185,
#               0.0296296296296296],
#              'RBFOX2_ai_FOX2-MinA_cleaned': [0.0519125683060109,
#               0.0546448087431694,
#               0.0546448087431694,
#               0.0573770491803278,
#               0.0437158469945355,
#               0.0491803278688524,
#               0.0532786885245901,
#               0.0450819672131147,
#               0.0560109289617486,
#               0.0450819672131147,
#               0.0519125683060109,
#               0.0628415300546448,
#               0.0382513661202185,
#               0.040983606557377,
#               0.0560109289617486,
#               0.0437158469945355,
#               0.064207650273224,
#               0.0478142076502732,
#               0.0450819672131147,
#               0.0505464480874316],
#              'RBFOX2_ai_FOX2-P0078_cleaned': [0.0355816831683168,
#               0.0349628712871287,
#               0.0337252475247524,
#               0.0355816831683168,
#               0.03125,
#               0.0331064356435643,
#               0.036509900990099,
#               0.0355816831683168,
#               0.0355816831683168,
#               0.0331064356435643,
#               0.0358910891089108,
#               0.0337252475247524,
#               0.0318688118811881,
#               0.0371287128712871,
#               0.0346534653465346,
#               0.0346534653465346,
#               0.0290841584158415,
#               0.0324876237623762,
#               0.0346534653465346,
#               0.0340346534653465],
#              'RBFOX2_both_FOX2-P0078_cleaned': [0.0307730798098573,
#               0.0270202651988991,
#               0.0312734550913184,
#               0.0327745809357017,
#               0.0337753314986239,
#               0.0322742056542406,
#               0.0317738303727795,
#               0.0347760820615461,
#               0.0335251438578934,
#               0.0347760820615461,
#               0.0375281461095821,
#               0.031523642732049,
#               0.0355266449837378,
#               0.0302727045283962,
#               0.034275706780085,
#               0.0280210157618213,
#               0.0297723292469352,
#               0.0332749562171628,
#               0.0300225168876657,
#               0.0292719539654741],
#              'RBFOX2_ct_FOX2-8e_cleaned': [0.015130674002751,
#               0.0096286107290233,
#               0.0110041265474552,
#               0.0096286107290233,
#               0.0110041265474552,
#               0.0082530949105914,
#               0.0110041265474552,
#               0.0068775790921595,
#               0.0110041265474552,
#               0.0110041265474552,
#               0.0068775790921595,
#               0.0068775790921595,
#               0.0096286107290233,
#               0.0096286107290233,
#               0.0137551581843191,
#               0.0137551581843191,
#               0.0055020632737276,
#               0.0137551581843191,
#               0.0137551581843191,
#               0.0110041265474552],
#              'RBFOX2_ct_FOX2-APOBEC1_cleaned': [0.0443271767810026,
#               0.0401055408970976,
#               0.0385224274406332,
#               0.0364116094986807,
#               0.0406332453825857,
#               0.0379947229551451,
#               0.0437994722955145,
#               0.0432717678100263,
#               0.0427440633245382,
#               0.0411609498680738,
#               0.0406332453825857,
#               0.0406332453825857,
#               0.041688654353562,
#               0.0469656992084432,
#               0.0395778364116095,
#               0.0390501319261213,
#               0.0364116094986807,
#               0.0379947229551451,
#               0.0406332453825857,
#               0.0374670184696569],
#              'RBFOX2_ct_FOX2-MinA_cleaned': [0.0118694362017804,
#               0.0148367952522255,
#               0.0148367952522255,
#               0.0089020771513353,
#               0.0118694362017804,
#               0.0178041543026706,
#               0.0178041543026706,
#               0.0,
#               0.0237388724035608,
#               0.0059347181008902,
#               0.0029673590504451,
#               0.0089020771513353,
#               0.0089020771513353,
#               0.0059347181008902,
#               0.0178041543026706,
#               0.0089020771513353,
#               0.0118694362017804,
#               0.0148367952522255,
#               0.0207715133531157,
#               0.0118694362017804],
#              'RBFOX2_ct_FOX2-P0078_cleaned': [0.0234986945169712,
#               0.0234986945169712,
#               0.0252393385552654,
#               0.0243690165361183,
#               0.0252393385552654,
#               0.0278503046127067,
#               0.0287206266318537,
#               0.0278503046127067,
#               0.0269799825935596,
#               0.0234986945169712,
#               0.0322019147084421,
#               0.0261096605744125,
#               0.031331592689295,
#               0.0287206266318537,
#               0.031331592689295,
#               0.0226283724978241,
#               0.0243690165361183,
#               0.0278503046127067,
#               0.0295909486510008,
#               0.0261096605744125]})

# %% [markdown]
# ### Find actual fraction with motif

# %%
from pyfaidx import Fasta
import re
fasta = '/projects/ps-yeolab3/ekofman/ReferenceData/hg38/cellranger-GRCh38-3.0.0/fasta/genome.fa'
FA = Fasta(fasta, rebuild=False)
import math

def get_sequence(r): 
    chrom = str(r.chrom)
    start = r.start
    end = r.end
    strand = r.strand
    
    sequence = FA[chrom][start:end].seq
    sequence = sequence.upper()
        
    return sequence

def get_extended_sequence(r): 
    chrom = str(r.chrom)
    
    midpoint = r.start + (int((r.end - r.start)/2))
    start = midpoint - 400
    end = midpoint + 400
    strand = r.strand
    
    sequence = FA[chrom][start:end].seq
    sequence = sequence.upper()
        
    return sequence

complement = {'A': 'T', 'C': 'G', 'G': 'C', 'T': 'A'}
def reverse_complement(seq):
    return "".join(complement.get(base, base) for base in reversed(seq))

def reverse(seq):
    return seq[::-1]

def motif_present(sequence, motif, strand):
    if strand == '+':
        return motif in sequence
    elif strand == '-':
        return reverse_complement(motif) in sequence

def motif_distance_from_center(sequence, motif, strand):
    #print(sequence)
    if strand == '+':
        search_term = motif
    elif strand == '-':
        search_term = reverse_complement(motif)
    else:
        search_term = motif
        
    if search_term in sequence:
        closest_position_in_first_half = 1000
        closest_position_in_second_half = 1000
        
        midpoint = math.ceil(len(sequence)/2)
        #print('\tmidpoint is {}'.format(midpoint))
        start_of_second_half = midpoint-len(motif)

        sequence_first_half = sequence[0:midpoint]
        sequence_second_half = sequence[start_of_second_half:]

        #print('\tSplit:', sequence_first_half, sequence_second_half)
        if search_term in sequence_first_half:
            flipped_sequence = reverse(sequence_first_half)
            flipped_search_term = reverse(search_term)
            
            #print('searching for {} in {}'.format(flipped_search_term, flipped_sequence))
            closest_position_in_first_half = - flipped_sequence.index(flipped_search_term) - math.floor(len(motif)/2)
            
        if search_term in sequence_second_half:
            closest_position_in_second_half = sequence_second_half.index(search_term) - math.floor(len(motif)/2)

        #print([closest_position_in_first_half, closest_position_in_second_half])
        if min(abs(closest_position_in_second_half), abs(closest_position_in_first_half)) == abs(closest_position_in_second_half):
            return closest_position_in_second_half
        else:
            return closest_position_in_first_half
    else:
        return None
    
motifs = ['TGCATG', 'GAATG', 'GTTTG', 'GTGTG', 'GTATG', 'GCTTG', 'GCCTG']

def add_sequence_presences(r, window_size=70):
    extended_sequence = r['extended_sequence(+)']
    strand = r.strand

    distance_tgcatg = motif_distance_from_center(extended_sequence, 'TGCATG', strand)
    distance_gcatg = motif_distance_from_center(extended_sequence, 'GCATG', strand)
    distance_gaatg = motif_distance_from_center(extended_sequence, 'TGAATG', strand)
    distance_gtttg = motif_distance_from_center(extended_sequence, 'TGAATG', strand)
    distance_gtgtg = motif_distance_from_center(extended_sequence, 'TGTGTG', strand)
    distance_gtatg = motif_distance_from_center(extended_sequence, 'TGTATG', strand)
    distance_gcttg = motif_distance_from_center(extended_sequence, 'TGCTTG', strand)
    distance_gcctg = motif_distance_from_center(extended_sequence, 'TGCCTG', strand)


    sequence = r['sequence(+)']

    presence_map = {motif: motif_present(sequence, motif, strand) for motif in motifs}
    return presence_map.get(motifs[0]), presence_map.get(motifs[1]), presence_map.get(motifs[2]), presence_map.get(motifs[3]), presence_map.get(motifs[4]), presence_map.get(motifs[5]), presence_map.get(motifs[6]), distance_tgcatg, distance_gcatg,distance_gaatg,distance_gtttg,distance_gtgtg,distance_gtatg,distance_gcttg,distance_gcctg


def calculate_fractions(p_df):
    fractions_dict = {}
    counts_dict = {}
    
    for motif in motifs + ['any_motif']:
        motif_present_count = p_df[motif].sum()
        motif_present_fraction = motif_present_count/len(p_df)
        fractions_dict[motif] = motif_present_fraction
        counts_dict[motif] = motif_present_count
    
    return fractions_dict, counts_dict

# %%
peak_filepaths = sorted(glob('6_overlapped_confident_peaks/*.tsv'))

stamp_file_dfs = {}

for peak_filepath in peak_filepaths:    
    print(peak_filepath)
    file_id = peak_filepath.split('/')[-1].split('.tsv')[0]
    if 'SLBP' not in file_id:
        print('\t', file_id)
        stamp_file_dfs[file_id] = pd.read_csv(peak_filepath, sep='\t', index_col=0)
# Out:
# 6_overlapped_confident_peaks/RBFOX2_ai_8e_alone.tsv
# 	 RBFOX2_ai_8e_alone
# 6_overlapped_confident_peaks/RBFOX2_ai_APOBEC1_alone.tsv
# 	 RBFOX2_ai_APOBEC1_alone
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-8e.tsv
# 	 RBFOX2_ai_FOX2-8e
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-8e_cleaned.tsv
# 	 RBFOX2_ai_FOX2-8e_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-APOBEC1.tsv
# 	 RBFOX2_ai_FOX2-APOBEC1
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-APOBEC1_cleaned.tsv
# 	 RBFOX2_ai_FOX2-APOBEC1_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-MinA.tsv
# 	 RBFOX2_ai_FOX2-MinA
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-MinA_cleaned.tsv
# 	 RBFOX2_ai_FOX2-MinA_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-P0078.tsv
# 	 RBFOX2_ai_FOX2-P0078
# 6_overlapped_confident_peaks/RBFOX2_ai_FOX2-P0078_cleaned.tsv
# 	 RBFOX2_ai_FOX2-P0078_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ai_MinA_alone.tsv
# 	 RBFOX2_ai_MinA_alone
# 6_overlapped_confident_peaks/RBFOX2_ai_P0078_alone.tsv
# 	 RBFOX2_ai_P0078_alone
# 6_overlapped_confident_peaks/RBFOX2_ai_p0078_alone.tsv
# 	 RBFOX2_ai_p0078_alone
# 6_overlapped_confident_peaks/RBFOX2_both_FOX2-P0078.tsv
# 	 RBFOX2_both_FOX2-P0078
# 6_overlapped_confident_peaks/RBFOX2_both_FOX2-P0078_cleaned.tsv
# 	 RBFOX2_both_FOX2-P0078_cleaned
# 6_overlapped_confident_peaks/RBFOX2_both_P0078_alone.tsv
# 	 RBFOX2_both_P0078_alone
# 6_overlapped_confident_peaks/RBFOX2_ct_8e_alone.tsv
# 	 RBFOX2_ct_8e_alone
# 6_overlapped_confident_peaks/RBFOX2_ct_APOBEC1_alone.tsv
# 	 RBFOX2_ct_APOBEC1_alone
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-8e.tsv
# 	 RBFOX2_ct_FOX2-8e
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-8e_cleaned.tsv
# 	 RBFOX2_ct_FOX2-8e_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-APOBEC1.tsv
# 	 RBFOX2_ct_FOX2-APOBEC1
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-APOBEC1_cleaned.tsv
# 	 RBFOX2_ct_FOX2-APOBEC1_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-MinA.tsv
# 	 RBFOX2_ct_FOX2-MinA
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-MinA_cleaned.tsv
# 	 RBFOX2_ct_FOX2-MinA_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-P0078.tsv
# 	 RBFOX2_ct_FOX2-P0078
# 6_overlapped_confident_peaks/RBFOX2_ct_FOX2-P0078_cleaned.tsv
# 	 RBFOX2_ct_FOX2-P0078_cleaned
# 6_overlapped_confident_peaks/RBFOX2_ct_MinA_alone.tsv
# 	 RBFOX2_ct_MinA_alone
# 6_overlapped_confident_peaks/RBFOX2_ct_P0078_alone.tsv
# 	 RBFOX2_ct_P0078_alone
# 6_overlapped_confident_peaks/RBFOX2_ct_p0078_alone.tsv
# 	 RBFOX2_ct_p0078_alone
# 6_overlapped_confident_peaks/SLBP_ai_8e_Only.tsv
# 6_overlapped_confident_peaks/SLBP_ai_APOBEC1_Only.tsv
# 6_overlapped_confident_peaks/SLBP_ai_MinA_Only.tsv
# 6_overlapped_confident_peaks/SLBP_ai_P0078_Only.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-8e.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-8e_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-APOBEC1.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-APOBEC1_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-MinA.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-MinA_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-P0078.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-P0078_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ai_SLBP-p0078.tsv
# 6_overlapped_confident_peaks/SLBP_both_P0078_Only.tsv
# 6_overlapped_confident_peaks/SLBP_both_SLBP-P0078.tsv
# 6_overlapped_confident_peaks/SLBP_both_SLBP-P0078_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ct_8e_Only.tsv
# 6_overlapped_confident_peaks/SLBP_ct_APOBEC1_Only.tsv
# 6_overlapped_confident_peaks/SLBP_ct_MinA_Only.tsv
# 6_overlapped_confident_peaks/SLBP_ct_P0078_Only.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-8e.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-8e_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-APOBEC1.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-APOBEC1_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-MinA.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-MinA_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-P0078.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-P0078_cleaned.tsv
# 6_overlapped_confident_peaks/SLBP_ct_SLBP-p0078.tsv

# %%
motifs = ['TGCATG', 'GAATG', 'GTTTG', 'GTGTG', 'GTATG', 'GCTTG', 'GCCTG']

# %%
from collections import defaultdict

actual_motif_fractions = defaultdict(lambda:{})
dfs_with_motif_info = {}
for label,df in stamp_file_dfs.items():
    print(label)
    print('\t', len(df))
    df['sequence(+)'] = df.apply(get_sequence, axis=1)
    df['extended_sequence(+)'] = df.apply(get_extended_sequence, axis=1)

    df[motifs[0]],df[motifs[1]],df[motifs[2]],df[motifs[3]],df[motifs[4]],df[motifs[5]],df[motifs[6]],df['TGCATG_dist_from_center'], df['GCATG_dist_from_center'],df['GAATG_dist_from_center'], df['GTTTG_dist_from_center'],df['GTGTG_dist_from_center'],df['GTATG_dist_from_center'], df['GCTTG_dist_from_center'],df['GCCTG_dist_from_center'] = zip(*df.apply(add_sequence_presences, axis=1))

    df['any_motif'] = df[[motifs[0], motifs[1], motifs[2], motifs[3], motifs[4], motifs[5], motifs[6]]].any(axis=1)
    dfs_with_motif_info[label] = df
    
    for motif in motifs + ['any_motif']:
        print('Checking {}'.format(motif))
        actual_motif_fractions[label][motif] = len(df[df[motif] == True])/len(df)
# Out:
# RBFOX2_ai_8e_alone
# 	 10809
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_APOBEC1_alone
# 	 488
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_FOX2-8e
# 	 9403
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_FOX2-8e_cleaned
# 	 7882
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_FOX2-APOBEC1
# 	 783
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_FOX2-APOBEC1_cleaned
# 	 540
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_FOX2-MinA
# 	 933
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_FOX2-MinA_cleaned
# 	 736
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_FOX2-P0078
# 	 4328
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_FOX2-P0078_cleaned
# 	 3236
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_MinA_alone
# 	 545
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_P0078_alone
# 	 5251
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ai_p0078_alone
# 	 5255
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_both_FOX2-P0078
# 	 5476
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_both_FOX2-P0078_cleaned
# 	 4003
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_both_P0078_alone
# 	 6667
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_8e_alone
# 	 382
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_APOBEC1_alone
# 	 2047
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_FOX2-8e
# 	 893
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_FOX2-8e_cleaned
# 	 729
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_FOX2-APOBEC1
# 	 2257
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_FOX2-APOBEC1_cleaned
# 	 1897
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_FOX2-MinA
# 	 513
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_FOX2-MinA_cleaned
# 	 338
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_FOX2-P0078
# 	 1622
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_FOX2-P0078_cleaned
# 	 1151
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_MinA_alone
# 	 470
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_P0078_alone
# 	 1911
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif
# RBFOX2_ct_p0078_alone
# 	 1916
# Checking TGCATG
# Checking GAATG
# Checking GTTTG
# Checking GTGTG
# Checking GTATG
# Checking GCTTG
# Checking GCCTG
# Checking any_motif

# %%
# plot options
to_plot_together_label = ['RBFOX2_ai_FOX2-MinA',
                          'RBFOX2_ai_MinA_alone',
                          'RBFOX2_ai_FOX2-8e',
                          'RBFOX2_ai_8e_alone',
                          'RBFOX2_ct_FOX2-APOBEC1',
                          'RBFOX2_ct_APOBEC1_alone',
                          'RBFOX2_both_FOX2-P0078',
                          'RBFOX2_both_P0078_alone']

to_plot_together_label_cleaned_comparison = ['RBFOX2_ai_FOX2-MinA_cleaned',
                          'RBFOX2_ai_FOX2-MinA',
                          'RBFOX2_ai_FOX2-8e_cleaned',
                          'RBFOX2_ai_FOX2-8e',
                          'RBFOX2_ct_FOX2-APOBEC1_cleaned',
                          'RBFOX2_ct_FOX2-APOBEC1',
                          'RBFOX2_both_FOX2-P0078_cleaned',
                          'RBFOX2_both_FOX2-P0078'
                         ]

to_plot_together_label_cleaned_comparison_plus_alone = ['RBFOX2_ai_FOX2-MinA_cleaned',
                          'RBFOX2_ai_FOX2-MinA',
                          'RBFOX2_ai_MinA_alone',
                          'RBFOX2_ai_FOX2-8e_cleaned',
                          'RBFOX2_ai_FOX2-8e',
                          'RBFOX2_ai_8e_alone',                    
                          'RBFOX2_ct_FOX2-APOBEC1_cleaned',
                          'RBFOX2_ct_FOX2-APOBEC1',
                          'RBFOX2_ct_APOBEC1_alone',
                          'RBFOX2_both_FOX2-P0078_cleaned',
                          'RBFOX2_both_FOX2-P0078',
                          'RBFOX2_both_P0078_alone'
                         ]

to_plot_together_label_only_cleaned = [
    'RBFOX2_ai_FOX2-MinA_cleaned',
    'RBFOX2_ai_FOX2-8e_cleaned',
    'RBFOX2_ct_FOX2-APOBEC1_cleaned',   
    'RBFOX2_both_FOX2-P0078_cleaned'
]

# %%
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns

custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="whitegrid", rc=custom_params, font_scale=1.5)

label_options = [to_plot_together_label, 
                 to_plot_together_label_cleaned_comparison, 
                 to_plot_together_label_cleaned_comparison_plus_alone, 
                 to_plot_together_label_only_cleaned]

title_base = 'stamp_peak_tgcatg_motif_permutation-'
title_options = ['rbp_enzyme_and_enzyme_alone',
                 'rbp_enzyme_and_rbp_cleaned_comparison',
                 'rbp_enzyme_rbp_cleaned_and_enzyme_alone',
                 'rbp_cleaned_only'
                ]


for labels_subset, title_suffix in zip(label_options, title_options):
    print(title_suffix)
    
    for l in labels_subset:
        assert(l in peak_set_to_motif_presence.keys())


    # Plot boxplots
    plt.figure(figsize=(7, 6))

    a = plt.boxplot([peak_set_to_motif_presence.get(l) for l in labels_subset]
                    , vert=False, showfliers=False)

    range_array= [i+1 for i in range(len(labels_subset))]

    b = plt.scatter([actual_motif_fractions.get(l).get('TGCATG') for l in labels_subset], range_array, color='k')
    plt.xlabel("Fraction")
    plt.title("Actual vs permuted fraction of STAMP peaks with TGCATG motif")
    c = plt.yticks(range_array, labels_subset)

    filename = '{}/{}{}'.format(figures_directory, title_base, title_suffix)
    print('\t', filename)
    plt.savefig('{}-box.png'.format(filename), bbox_inches='tight')
    plt.savefig('{}-box.svg'.format(filename), bbox_inches='tight')


    # Plot enrichment

    tick_list = labels_subset

    motif_odds_ratios = {}
    for k in peak_set_to_motif_presence.keys():

        permuted_val = np.mean(peak_set_to_motif_presence.get(k))
        actual_val = actual_motif_fractions.get(k).get('TGCATG')
        
        num_exceeding_actual = [v for v in peak_set_to_motif_presence.get(k) if v > actual_val]
        pval = len(num_exceeding_actual)/len(peak_set_to_motif_presence.get(k))
        print(k, pval)
        motif_odds_ratios[k] = actual_val/permuted_val

    ordered_motif_ors = []
    for o in tick_list:
        ordered_motif_ors.append(motif_odds_ratios.get(o))

    min_odds_ratio = np.min(ordered_motif_ors)
    max_odds_ratio = np.max(ordered_motif_ors)
    
    plt.figure(figsize=(5, 6))
    plt.barh(tick_list, ordered_motif_ors, color='k')
    plt.xlim(min_odds_ratio-0.1,max_odds_ratio+0.1)
    plt.title("Enrichment")
    
    plt.savefig('{}-enrich.png'.format(filename), bbox_inches='tight')
    plt.savefig('{}-enrich.svg'.format(filename), bbox_inches='tight')
# Out:
# rbp_enzyme_and_enzyme_alone
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/Figures/RBFOX2_motif_permutations//stamp_peak_tgcatg_motif_permutation-rbp_enzyme_and_enzyme_alone
# RBFOX2_ai_8e_alone 0.5
# RBFOX2_ai_APOBEC1_alone 0.1
# RBFOX2_ai_FOX2-8e 0.0
# RBFOX2_ai_FOX2-APOBEC1 0.0
# RBFOX2_ai_FOX2-MinA 0.0
# RBFOX2_ai_FOX2-P0078 0.0
# RBFOX2_ai_MinA_alone 0.25
# RBFOX2_ai_P0078_alone 1.0
# RBFOX2_ai_p0078_alone 1.0
# RBFOX2_both_FOX2-P0078 0.0
# RBFOX2_both_P0078_alone 0.95
# RBFOX2_ct_8e_alone 0.65
# RBFOX2_ct_APOBEC1_alone 0.85
# RBFOX2_ct_FOX2-8e 0.9
# RBFOX2_ct_FOX2-APOBEC1 0.0
# RBFOX2_ct_FOX2-MinA 0.9
# RBFOX2_ct_FOX2-P0078 0.4
# RBFOX2_ct_MinA_alone 0.05
# RBFOX2_ct_P0078_alone 0.55
# RBFOX2_ct_p0078_alone 0.45
# RBFOX2_ai_FOX2-8e_cleaned 0.0
# RBFOX2_ai_FOX2-APOBEC1_cleaned 0.0
# RBFOX2_ai_FOX2-MinA_cleaned 0.0
# RBFOX2_ai_FOX2-P0078_cleaned 0.0
# RBFOX2_both_FOX2-P0078_cleaned 0.0
# RBFOX2_ct_FOX2-8e_cleaned 1.0
# RBFOX2_ct_FOX2-APOBEC1_cleaned 0.0
# RBFOX2_ct_FOX2-MinA_cleaned 0.95
# RBFOX2_ct_FOX2-P0078_cleaned 0.2
# rbp_enzyme_and_rbp_cleaned_comparison
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/Figures/RBFOX2_motif_permutations//stamp_peak_tgcatg_motif_permutation-rbp_enzyme_and_rbp_cleaned_comparison
# RBFOX2_ai_8e_alone 0.5
# RBFOX2_ai_APOBEC1_alone 0.1
# RBFOX2_ai_FOX2-8e 0.0
# RBFOX2_ai_FOX2-APOBEC1 0.0
# RBFOX2_ai_FOX2-MinA 0.0
# RBFOX2_ai_FOX2-P0078 0.0
# RBFOX2_ai_MinA_alone 0.25
# RBFOX2_ai_P0078_alone 1.0
# RBFOX2_ai_p0078_alone 1.0
# RBFOX2_both_FOX2-P0078 0.0
# RBFOX2_both_P0078_alone 0.95
# RBFOX2_ct_8e_alone 0.65
# RBFOX2_ct_APOBEC1_alone 0.85
# RBFOX2_ct_FOX2-8e 0.9
# RBFOX2_ct_FOX2-APOBEC1 0.0
# RBFOX2_ct_FOX2-MinA 0.9
# RBFOX2_ct_FOX2-P0078 0.4
# RBFOX2_ct_MinA_alone 0.05
# RBFOX2_ct_P0078_alone 0.55
# RBFOX2_ct_p0078_alone 0.45
# RBFOX2_ai_FOX2-8e_cleaned 0.0
# RBFOX2_ai_FOX2-APOBEC1_cleaned 0.0
# RBFOX2_ai_FOX2-MinA_cleaned 0.0
# RBFOX2_ai_FOX2-P0078_cleaned 0.0
# RBFOX2_both_FOX2-P0078_cleaned 0.0
# RBFOX2_ct_FOX2-8e_cleaned 1.0
# RBFOX2_ct_FOX2-APOBEC1_cleaned 0.0
# RBFOX2_ct_FOX2-MinA_cleaned 0.95
# RBFOX2_ct_FOX2-P0078_cleaned 0.2
# rbp_enzyme_rbp_cleaned_and_enzyme_alone
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/Figures/RBFOX2_motif_permutations//stamp_peak_tgcatg_motif_permutation-rbp_enzyme_rbp_cleaned_and_enzyme_alone
# RBFOX2_ai_8e_alone 0.5
# RBFOX2_ai_APOBEC1_alone 0.1
# RBFOX2_ai_FOX2-8e 0.0
# RBFOX2_ai_FOX2-APOBEC1 0.0
# RBFOX2_ai_FOX2-MinA 0.0
# RBFOX2_ai_FOX2-P0078 0.0
# RBFOX2_ai_MinA_alone 0.25
# RBFOX2_ai_P0078_alone 1.0
# RBFOX2_ai_p0078_alone 1.0
# RBFOX2_both_FOX2-P0078 0.0
# RBFOX2_both_P0078_alone 0.95
# RBFOX2_ct_8e_alone 0.65
# RBFOX2_ct_APOBEC1_alone 0.85
# RBFOX2_ct_FOX2-8e 0.9
# RBFOX2_ct_FOX2-APOBEC1 0.0
# RBFOX2_ct_FOX2-MinA 0.9
# RBFOX2_ct_FOX2-P0078 0.4
# RBFOX2_ct_MinA_alone 0.05
# RBFOX2_ct_P0078_alone 0.55
# RBFOX2_ct_p0078_alone 0.45
# RBFOX2_ai_FOX2-8e_cleaned 0.0
# RBFOX2_ai_FOX2-APOBEC1_cleaned 0.0
# RBFOX2_ai_FOX2-MinA_cleaned 0.0
# RBFOX2_ai_FOX2-P0078_cleaned 0.0
# RBFOX2_both_FOX2-P0078_cleaned 0.0
# RBFOX2_ct_FOX2-8e_cleaned 1.0
# RBFOX2_ct_FOX2-APOBEC1_cleaned 0.0
# RBFOX2_ct_FOX2-MinA_cleaned 0.95
# RBFOX2_ct_FOX2-P0078_cleaned 0.2
# rbp_cleaned_only
# 	 /projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/Figures/RBFOX2_motif_permutations//stamp_peak_tgcatg_motif_permutation-rbp_cleaned_only
# RBFOX2_ai_8e_alone 0.5
# RBFOX2_ai_APOBEC1_alone 0.1
# RBFOX2_ai_FOX2-8e 0.0
# RBFOX2_ai_FOX2-APOBEC1 0.0
# RBFOX2_ai_FOX2-MinA 0.0
# RBFOX2_ai_FOX2-P0078 0.0
# RBFOX2_ai_MinA_alone 0.25
# RBFOX2_ai_P0078_alone 1.0
# RBFOX2_ai_p0078_alone 1.0
# RBFOX2_both_FOX2-P0078 0.0
# RBFOX2_both_P0078_alone 0.95
# RBFOX2_ct_8e_alone 0.65
# RBFOX2_ct_APOBEC1_alone 0.85
# RBFOX2_ct_FOX2-8e 0.9
# RBFOX2_ct_FOX2-APOBEC1 0.0
# RBFOX2_ct_FOX2-MinA 0.9
# RBFOX2_ct_FOX2-P0078 0.4
# RBFOX2_ct_MinA_alone 0.05
# RBFOX2_ct_P0078_alone 0.55
# RBFOX2_ct_p0078_alone 0.45
# RBFOX2_ai_FOX2-8e_cleaned 0.0
# RBFOX2_ai_FOX2-APOBEC1_cleaned 0.0
# RBFOX2_ai_FOX2-MinA_cleaned 0.0
# RBFOX2_ai_FOX2-P0078_cleaned 0.0
# RBFOX2_both_FOX2-P0078_cleaned 0.0
# RBFOX2_ct_FOX2-8e_cleaned 1.0
# RBFOX2_ct_FOX2-APOBEC1_cleaned 0.0
# RBFOX2_ct_FOX2-MinA_cleaned 0.95
# RBFOX2_ct_FOX2-P0078_cleaned 0.2

# %% [markdown]
# # Distance from center of GCATG motif

# %%
to_plot_together = {}


for experiment in to_plot_together_label:
    print(experiment)
    df = dfs_with_motif_info.get(experiment)
    df_with_dists = df[~df.TGCATG_dist_from_center.isna()]
    
    to_plot_together[experiment] = df_with_dists
        
    #c = plt.figure()
    #b = sns.distplot(df_with_dists.TGCATG_dist_from_center, bins=50)
    #a = plt.title('{} Distribution of Closest TGCATG motif distance from center'.format(experiment))

distance_columns = [c for c in list(df.columns[-9:]) if 'dist' in c]

for c in distance_columns:
    legend = []
    plt.figure(figsize=(14, 10))
    for label, df in to_plot_together.items():
        legend.append(label)
        plt.xlim(-350, 350)
        g = sns.distplot(df[c], hist=False, kde_kws=dict(linewidth=5))
    g.set(yticklabels=[])
    plt.legend(legend)
    motif_label = c.split('_')[0]
    plt.xlabel("Distance from peak center to closest instance of {}".format(motif_label))
    plt.ylabel("Density")
    plt.title("Distribution of distance to closest {} across peak sets".format(motif_label))
    plt.savefig('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/Figures/RBFOX2_motif_distance_to_center/{}_distance_to_center.png'.format(motif_label), bbox_inches='tight')
    plt.savefig('/projects/ps-yeolab3/ekofman/Hugo/Full_RBFOX2_and_SLBP/Figures/RBFOX2_motif_distance_to_center/{}_distance_to_center.svg'.format(motif_label),bbox_inches='tight')

    break
# Out:
# RBFOX2_ai_FOX2-MinA
# RBFOX2_ai_MinA_alone
# RBFOX2_ai_FOX2-8e
# RBFOX2_ai_8e_alone
# RBFOX2_ct_FOX2-APOBEC1
# RBFOX2_ct_APOBEC1_alone
# RBFOX2_both_FOX2-P0078
# RBFOX2_both_P0078_alone
# /home/ekofman/new_anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/ekofman/new_anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/ekofman/new_anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/ekofman/new_anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/ekofman/new_anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/ekofman/new_anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/ekofman/new_anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/ekofman/new_anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
